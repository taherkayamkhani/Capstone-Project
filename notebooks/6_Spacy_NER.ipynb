# %% [markdown]
# ### <span style="color:#800000">NER using spaCy</span>

# %% [markdown]
# ### <span style="color:#FF00FF">Import libraries</span>

# %%
import pandas as pd
import ast
import pickle

import spacy
from spacy import displacy
from spacy.training import Example
from spacy.util import minibatch, compounding

from seqeval.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %% [markdown]
# ### <span style="color:#FF00FF">Load the dataset</span>

# %%
# Reading data and creating the dataframe 
df = pd.read_csv("../data/jobdescriptions_train.csv")

# Checking the first 5 rows of the data
df.head()
# Out:
#                         domain  \
# 0  information-technology-jobs
# 1  information-technology-jobs
# 2  information-technology-jobs
# 3  information-technology-jobs
# 4  information-technology-jobs
#
#                                                 link  \
# 0  https://www.naukri.com/job-listings-head-infor...
# 1  https://www.naukri.com/job-listings-urgent-ope...
# 2  https://www.naukri.com/job-listings-informatio...
# 3  https://www.naukri.com/job-listings-senior-sol...
# 4  https://www.naukri.com/job-listings-informatio...
#
#                                                title  \
# 0                      Head - Information Technology
# 1  Urgent Opening - Sr. Executive- IT (informatio...
# 2  Information Technology (IT) & Business Solutio...
# 3   Senior Solution Manager - Information Technology
# 4                             Information Technology
#
#                         company     experience                       salary  \
# 0             Bright Consultant  15 - 25 years                Not Disclosed
# 1  Ecom Express Private Limited    4 - 9 years  ₹ 2,50,000 - 4,50,000 P.A.
# 2              Procter & Gamble   8 - 10 years                Not Disclosed
# 3              Procter & Gamble   8 - 12 years                Not Disclosed
# 4                     Stefanini  12 - 22 years                Not Disclosed
#
#       location                                        description  \
# 0  Delhi / NCR   : - manage all it verticals of the company li...
# 1    Ahmedabad  hi, greetings from ecom express pvt ltd!!! we ...
# 2       Mumbai    do  you want to join our team of women and m...
# 3       Mumbai       solutions manager leads product roadmap, ...
# 4        Noida     we are looking for someone who is passionat...
#
#                              role  \
# 0  Head/VP/GM-Technology(IT)/CTO,
# 1          IT/Networking-Manager,
# 2    Project Manager-IT/Software,
# 3          IT/Networking-Manager,
# 4           System Administrator,
#
#                                      industry_type  \
# 0            Industrial Products, Heavy Machinery,
# 1  Courier, Transportation, Freight , Warehousing,
# 2                           FMCG, Foods, Beverage,
# 3                           FMCG, Foods, Beverage,
# 4                           Recruitment, Staffing,
#
#                                        qualification  \
# 0  ['UG :Any Graduate in Any Specialization', 'PG...
# 1         ['UG :Any Graduate in Any Specialization']
# 2  ['UG :BCA in Computers, B.Tech/B.E. in Compute...
# 3  ['UG :Any Graduate in Any Specialization', 'PG...
# 4  ['UG :Any Graduate in Any Specialization', 'PG...
#
#                                      functional_area       employment_type  \
# 0    IT Software - Network Administration, Security,  Full Time, Permanent
# 1  IT Software - Application Programming, Mainten...  Full Time, Permanent
# 2  IT Software - Application Programming, Mainten...  Full Time, Permanent
# 3  IT Software - Application Programming, Mainten...  Full Time, Permanent
# 4  IT Software - Application Programming, Mainten...  Full Time, Permanent
#
#                                 role_category  \
# 0                           Senior Management
# 1  Admin/Maintenance/Security/Datawarehousing
# 2                          Project Management
# 3  Admin/Maintenance/Security/Datawarehousing
# 4  Admin/Maintenance/Security/Datawarehousing
#
#                                               skills  \
# 0  ['Network Security', 'Information Security', '...
# 1  ['LAN Troubleshooting', 'Hardware Networking',...
# 2  ['Application Development', 'Agile Project Man...
# 3  ['Agile Methodology', 'Fund Management', 'Prod...
# 4  ['SAN', 'Automation', 'Debugging', 'NetBackup'...
#
#                                    clean_description  \
# 0  manage verticals company like applications inf...
# 1  hi greetings ecom express pvt ltd urgent openi...
# 2  want join team women men professionals apply s...
# 3  solutions manager leads product roadmap create...
# 4  looking someone passionate emerging technologi...
#
#                                                 tags
# 0  {'entities': [(323, 331, 'DEPT'), (30, 42, 'SK...
# 1  {'entities': [(394, 411, 'ROLE'), (602, 610, '...
# 2  {'entities': [(2005, 2021, 'DEPT'), (1954, 197...
# 3  {'entities': [(893, 913, 'SKILL'), (1061, 1075...
# 4  {'entities': [(3277, 3297, 'SKILL'), (2428, 24...

# %% [markdown]
# ### <span style="color:#FF00FF">Training spaCy NER model with Custom Entities</span>

# %%
TRAIN_DATA = df[['clean_description','tags']].to_numpy()

# %%
# Import and load the spacy model
nlp=spacy.load("en_core_web_sm") 

# Getting the ner component
ner=nlp.get_pipe('ner')

# Adding labels to the `ner`
ner.add_label('SKILL')
ner.add_label('ROLE')
ner.add_label('DEPT')

# Disable pipeline components you dont need to change
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
def train_spacy(data,iterations):
    TRAIN_DATA = data
    nlp = spacy.blank('en')  # create blank Language class
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'ner' not in nlp.pipe_names:
        nlp.add_pipe('ner', last=True)
       

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print("Statring iteration " + str(itn))
            #random.shuffle(TRAIN_DATA)
            losses = {}
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
            for batch in batches:
                examples = []
                for text, annots in batch:
                    annots = ast.literal_eval(annots)
                    examples.append(Example.from_dict(nlp.make_doc(text), annots))
                    nlp.update(examples,losses=losses)
                print("Losses", losses) 
    return nlp

# %%
jdnlp = train_spacy(TRAIN_DATA, iterations = 20)
# Out:
# Statring iteration 0
# Losses {'ner': 1342.587233364582}
# Losses {'ner': 2743.3319696187973}
# Losses {'ner': 3096.3558551976603}
# Losses {'ner': 3248.51164596506}
# Losses {'ner': 3485.070929487367}
# Losses {'ner': 3577.0816759230947}
# Losses {'ner': 3672.19098782129}
# Losses {'ner': 3848.342194174955}
# Losses {'ner': 4037.342335229405}
# Losses {'ner': 4217.378909881765}
# Losses {'ner': 4223.253225199043}
# Losses {'ner': 4586.481605743429}
# Losses {'ner': 4806.066182743514}
# Losses {'ner': 4999.260286738764}
# Losses {'ner': 5206.701077337718}
# Losses {'ner': 5378.515542241307}
# Losses {'ner': 5519.624816685284}
# Losses {'ner': 5678.549432656981}
# Losses {'ner': 5964.945157788162}
# Losses {'ner': 6156.00424803289}
# Losses {'ner': 6259.221911209092}
# Losses {'ner': 6345.93847689692}
# Losses {'ner': 6425.6806435405815}
# Losses {'ner': 6530.002227845231}
# Losses {'ner': 6581.830454928604}
# Losses {'ner': 6651.495613972318}
# Losses {'ner': 6699.395460488064}
# Losses {'ner': 6733.735351793318}
# Losses {'ner': 7042.6800613503765}
# Losses {'ner': 7090.842175733275}
# Losses {'ner': 7114.50740986115}
# Losses {'ner': 7129.866302241829}
# Losses {'ner': 7270.784945272578}
# Losses {'ner': 7312.354953948366}
# Losses {'ner': 7350.229731420348}
# Losses {'ner': 7457.326060582516}
# Losses {'ner': 7722.41257541438}
# Losses {'ner': 7905.455138825209}
# Losses {'ner': 7908.910362426646}
# Losses {'ner': 7993.041392978315}
# Losses {'ner': 8005.282242399019}
# Losses {'ner': 8008.036955352418}
# Losses {'ner': 8039.605186725931}
# Losses {'ner': 8135.218719031226}
# Losses {'ner': 8253.360284652863}
# Losses {'ner': 8288.59182686824}
# Losses {'ner': 8449.036917948346}
# Losses {'ner': 8593.940802888863}
# Losses {'ner': 8786.892195935068}
# Losses {'ner': 8995.5906201499}
# Losses {'ner': 9059.279277153524}
# Losses {'ner': 9171.310078203593}
# Losses {'ner': 9227.918447248268}
# Losses {'ner': 9360.757075301111}
# Losses {'ner': 9616.145966613069}
# Losses {'ner': 9789.640562621866}
# Losses {'ner': 9840.890570670988}
# Losses {'ner': 10002.629128693425}
# Losses {'ner': 10089.213695854065}
# Losses {'ner': 10132.529194465518}
# Losses {'ner': 10253.618557170652}
# Losses {'ner': 10372.934129122244}
# Losses {'ner': 10560.281405143487}
# Losses {'ner': 10714.646365800982}
# Losses {'ner': 10871.309812727335}
# Losses {'ner': 10955.616216921975}
# Losses {'ner': 11037.394289890011}
# Losses {'ner': 11146.160005608152}
# Losses {'ner': 11221.112702796727}
# Losses {'ner': 11297.691526719818}
# Losses {'ner': 11389.495211998774}
# Losses {'ner': 11456.665189061085}
# Losses {'ner': 11557.583929941813}
# Losses {'ner': 11645.95090642719}
# Losses {'ner': 11773.971820722523}
# Losses {'ner': 11884.03500224945}
# Losses {'ner': 11988.865014436595}
# Losses {'ner': 12200.445355952666}
# Losses {'ner': 12492.22753952138}
# Losses {'ner': 12641.652548742568}
# Losses {'ner': 12733.62308771307}
# Losses {'ner': 12815.906158409267}
# Losses {'ner': 12986.35973033082}
# Losses {'ner': 13114.956000573842}
# Losses {'ner': 13209.051395164304}
# Losses {'ner': 13260.132879805828}
# Losses {'ner': 13507.783215393736}
# Losses {'ner': 13591.79472822155}
# Losses {'ner': 13732.899180994593}
# Losses {'ner': 13780.327678885204}
# Losses {'ner': 13845.210425076233}
# Losses {'ner': 13861.037190573847}
# Losses {'ner': 14003.098544365532}
# Losses {'ner': 14016.994520031174}
# Losses {'ner': 14057.426150607582}
# Losses {'ner': 14127.862773315726}
# Losses {'ner': 14177.116845366312}
# Losses {'ner': 14197.774563857229}
# Losses {'ner': 14266.55648791809}
# Losses {'ner': 14304.027675908803}
# Losses {'ner': 14369.40366989927}
# Losses {'ner': 14461.648363009324}
# Losses {'ner': 14491.705914721899}
# Losses {'ner': 14516.269270142238}
# Losses {'ner': 14542.77022486851}
# Losses {'ner': 14591.770564217828}
# Losses {'ner': 14616.236362317573}
# Losses {'ner': 14650.043562234741}
# Losses {'ner': 14675.518876068223}
# Losses {'ner': 14699.28323754279}
# Losses {'ner': 14744.919938782441}
# Losses {'ner': 14793.814670851725}
# Losses {'ner': 14852.004431226627}
# Losses {'ner': 14905.777571761739}
# Losses {'ner': 14944.060656452075}
# Losses {'ner': 14972.573246924461}
# Losses {'ner': 15028.206190312943}
# Losses {'ner': 15092.742454703135}
# Losses {'ner': 15141.839497009452}
# Losses {'ner': 15213.236337706981}
# Losses {'ner': 15244.738199855745}
# Losses {'ner': 15285.884118358455}
# Losses {'ner': 15369.626669426054}
# Losses {'ner': 15446.465166105005}
# Losses {'ner': 15527.140747047382}
# Losses {'ner': 15582.146100165643}
# Losses {'ner': 15630.647764516356}
# Losses {'ner': 15697.168788564633}
# Losses {'ner': 15716.99575320277}
# Losses {'ner': 15771.164012378676}
# Losses {'ner': 15808.864373376786}
# Losses {'ner': 15926.9648250357}
# Losses {'ner': 15987.73775658552}
# Losses {'ner': 16043.92366801854}
# Losses {'ner': 16118.49074826276}
# Losses {'ner': 16232.438783996718}
# Losses {'ner': 16312.403875812211}
# Losses {'ner': 16475.284914739223}
# Losses {'ner': 16589.645476548718}
# Losses {'ner': 16808.213936379954}
# Losses {'ner': 17052.188463813673}
# Losses {'ner': 17129.38259935029}
# Losses {'ner': 17352.11291079991}
# Losses {'ner': 17389.312318415166}
# Losses {'ner': 17520.182198928655}
# Losses {'ner': 17572.657136320864}
# Losses {'ner': 17649.664710494155}
# Losses {'ner': 17805.817655680286}
# Losses {'ner': 17898.239477310988}
# Losses {'ner': 17992.889857209408}
# Losses {'ner': 18003.61312531322}
# Losses {'ner': 18072.65193258943}
# Losses {'ner': 18076.476948546675}
# Losses {'ner': 18104.75678350932}
# Losses {'ner': 18170.98335415452}
# Losses {'ner': 18206.526617347525}
# Losses {'ner': 18234.37466601814}
# Losses {'ner': 18264.479278966865}
# Losses {'ner': 18305.597215010457}
# Losses {'ner': 18340.659971953603}
# Losses {'ner': 18350.88741691989}
# Losses {'ner': 18441.22409367544}
# Losses {'ner': 18468.37429152088}
# Losses {'ner': 18494.284294678684}
# Losses {'ner': 18573.182530649443}
# Losses {'ner': 18645.71787172751}
# Losses {'ner': 18703.458541905376}
# Losses {'ner': 18708.530905849424}
# Losses {'ner': 18715.732932927058}
# Losses {'ner': 18766.86577043873}
# Losses {'ner': 18793.3669708862}
# Losses {'ner': 18821.214511724498}
# Losses {'ner': 18859.641976779003}
# Losses {'ner': 18933.415026521638}
# Losses {'ner': 18988.133273626147}
# Losses {'ner': 19000.77775042011}
# Losses {'ner': 19021.22114284064}
# Losses {'ner': 19077.901814313373}
# Losses {'ner': 19099.049671589688}
# Losses {'ner': 19113.754967375946}
# Losses {'ner': 19131.10296980017}
# Losses {'ner': 19160.389751253013}
# Losses {'ner': 19207.37512031192}
# Losses {'ner': 19257.787733358637}
# Losses {'ner': 19271.16905088293}
# Losses {'ner': 19284.95756375916}
# Losses {'ner': 19286.02060331291}
# Losses {'ner': 19312.72780643211}
# Losses {'ner': 19365.098818945997}
# Losses {'ner': 19403.555495089968}
# Losses {'ner': 19437.08314619562}
# Losses {'ner': 19456.145636941896}
# Losses {'ner': 19482.21580250051}
# Losses {'ner': 19488.643625297667}
# Losses {'ner': 19493.11771924188}
# Losses {'ner': 19497.227037187156}
# Losses {'ner': 19507.90814234035}
# Losses {'ner': 19529.030903434075}
# Losses {'ner': 19568.169219830077}
# Losses {'ner': 19674.919555412853}
# Losses {'ner': 19748.42236213403}
# Losses {'ner': 19820.429185027842}
# Losses {'ner': 19851.01654465387}
# Losses {'ner': 19877.970950978444}
# Losses {'ner': 19914.73476997578}
# Losses {'ner': 20019.24465304879}
# Losses {'ner': 20089.801406926075}
# Losses {'ner': 20148.890294154407}
# Losses {'ner': 20205.33010448149}
# Losses {'ner': 20333.939498848456}
# Losses {'ner': 20372.013834431506}
# Losses {'ner': 20496.126396795684}
# Losses {'ner': 20559.97039295432}
# Losses {'ner': 20626.215606884278}
# Losses {'ner': 20671.788884406553}
# Losses {'ner': 20712.830495160055}
# Losses {'ner': 20761.07251110396}
# Losses {'ner': 20856.152339388358}
# Losses {'ner': 20896.858236681404}
# Losses {'ner': 20957.02349714437}
# Losses {'ner': 20996.41900723503}
# Losses {'ner': 21067.906376836014}
# Losses {'ner': 21107.04684797373}
# Losses {'ner': 21145.237229301245}
# Losses {'ner': 21279.514800775127}
# Losses {'ner': 21432.75999576249}
# Losses {'ner': 21536.509956991646}
# Losses {'ner': 21572.952970843544}
# Losses {'ner': 21668.6481023572}
# Losses {'ner': 21720.936303732953}
# Losses {'ner': 21751.111351161187}
# Losses {'ner': 21854.460414769695}
# Losses {'ner': 21890.78254648669}
# Losses {'ner': 21919.389793163184}
# Losses {'ner': 21958.02993861169}
# Losses {'ner': 22142.93006681845}
# Losses {'ner': 22175.337639338002}
# Losses {'ner': 22206.325484215537}
# Losses {'ner': 22206.38918000078}
# Losses {'ner': 22243.784997221555}
# Losses {'ner': 22371.97039530121}
# Losses {'ner': 22723.369006428547}
# Losses {'ner': 22845.282118808358}
# Losses {'ner': 22908.702955355882}
# Losses {'ner': 22983.025613905676}
# Losses {'ner': 23037.91380912386}
# Losses {'ner': 23327.31329493604}
# Losses {'ner': 23427.833751988717}
# Losses {'ner': 23509.217903332705}
# Losses {'ner': 23741.39615825842}
# Losses {'ner': 23804.741285641558}
# Losses {'ner': 23872.600346320407}
# Losses {'ner': 23979.758151142294}
# Losses {'ner': 24062.726005040236}
# Losses {'ner': 24129.631004898525}
# Losses {'ner': 24240.236282358655}
# Losses {'ner': 24263.37152079195}
# Losses {'ner': 24330.549556522114}
# Losses {'ner': 24621.31388380903}
# Losses {'ner': 24644.097635435373}
# Losses {'ner': 24778.3135109937}
# Losses {'ner': 24799.853065368374}
# Losses {'ner': 24984.85482697691}
# Losses {'ner': 25070.749004105925}
# Losses {'ner': 25279.459913534964}
# Losses {'ner': 25407.846304736202}
# Losses {'ner': 25485.21274007273}
# Losses {'ner': 25620.46568995567}
# Losses {'ner': 25701.510190325655}
# Losses {'ner': 25754.584804136368}
# Losses {'ner': 25882.853790252673}
# Losses {'ner': 25990.31330316698}
# Losses {'ner': 26052.633479071537}
# Losses {'ner': 26087.94472416802}
# Losses {'ner': 26108.724591911934}
# Losses {'ner': 26157.82848139019}
# Losses {'ner': 26295.52670640016}
# Losses {'ner': 26396.682370676215}
# Losses {'ner': 26443.481803795865}
# Statring iteration 1
# Losses {'ner': 119.51127087489355}
# Losses {'ner': 319.2703217349829}
# Losses {'ner': 451.6329414340295}
# Losses {'ner': 527.4650534299439}
# Losses {'ner': 660.7437665374769}
# Losses {'ner': 694.0700065139978}
# Losses {'ner': 724.1150276956938}
# Losses {'ner': 787.0686228400641}
# Losses {'ner': 908.6869192550541}
# Losses {'ner': 980.3952790231085}
# Losses {'ner': 981.6250668571424}
# Losses {'ner': 1161.3713005518}
# Losses {'ner': 1294.170345826085}
# Losses {'ner': 1394.7317839507027}
# Losses {'ner': 1504.0459279377264}
# Losses {'ner': 1627.123011359184}
# Losses {'ner': 1670.9133273707516}
# Losses {'ner': 1778.6157728495182}
# Losses {'ner': 1855.7038058669593}
# Losses {'ner': 1891.9382315502805}
# Losses {'ner': 1932.512265588278}
# Losses {'ner': 1965.0743833258161}
# Losses {'ner': 2011.5928345054292}
# Losses {'ner': 2059.4151804344783}
# Losses {'ner': 2097.37223401845}
# Losses {'ner': 2160.6625263776823}
# Losses {'ner': 2199.871380268882}
# Losses {'ner': 2222.102912137657}
# Losses {'ner': 2368.233290992025}
# Losses {'ner': 2382.8267057018666}
# Losses {'ner': 2384.0782096600155}
# Losses {'ner': 2384.7937753258284}
# Losses {'ner': 2472.0200507672616}
# Losses {'ner': 2474.9620503541582}
# Losses {'ner': 2491.9694627959893}
# Losses {'ner': 2539.4602900209525}
# Losses {'ner': 2743.476060220855}
# Losses {'ner': 2857.42664589082}
# Losses {'ner': 2858.1431811707303}
# Losses {'ner': 2927.566919892204}
# Losses {'ner': 2927.6516076538887}
# Losses {'ner': 2928.923988849184}
# Losses {'ner': 2941.388991556675}
# Losses {'ner': 3035.398710902177}
# Losses {'ner': 3114.73719193438}
# Losses {'ner': 3145.6203295481764}
# Losses {'ner': 3262.273815618275}
# Losses {'ner': 3342.789932730867}
# Losses {'ner': 3491.099418288337}
# Losses {'ner': 3703.0831707923608}
# Losses {'ner': 3746.8808354103217}
# Losses {'ner': 3795.4768035939996}
# Losses {'ner': 3829.476590982257}
# Losses {'ner': 3947.0561721646536}
# Losses {'ner': 4137.238445259575}
# Losses {'ner': 4277.645664185942}
# Losses {'ner': 4314.356510772771}
# Losses {'ner': 4439.987873280838}
# Losses {'ner': 4504.439167378062}
# Losses {'ner': 4536.593389479111}
# Losses {'ner': 4641.570773852939}
# Losses {'ner': 4732.019195931372}
# Losses {'ner': 4885.65204755309}
# Losses {'ner': 5018.26778486316}
# Losses {'ner': 5158.65139518877}
# Losses {'ner': 5224.920322813067}
# Losses {'ner': 5287.161352256443}
# Losses {'ner': 5379.37812444472}
# Losses {'ner': 5422.49375948359}
# Losses {'ner': 5501.843052991578}
# Losses {'ner': 5561.2773445274925}
# Losses {'ner': 5612.858356680695}
# Losses {'ner': 5681.312008839103}
# Losses {'ner': 5759.3877955586995}
# Losses {'ner': 5860.382654572809}
# Losses {'ner': 5960.46007095399}
# Losses {'ner': 6033.985275271627}
# Losses {'ner': 6269.63019079634}
# Losses {'ner': 6577.276234339623}
# Losses {'ner': 6722.196865394035}
# Losses {'ner': 6816.408166606485}
# Losses {'ner': 6888.5253451922745}
# Losses {'ner': 7044.7884063122765}
# Losses {'ner': 7168.318255820078}
# Losses {'ner': 7240.402524303999}
# Losses {'ner': 7286.71481180392}
# Losses {'ner': 7495.134053514601}
# Losses {'ner': 7573.755879783574}
# Losses {'ner': 7720.529854698679}
# Losses {'ner': 7753.949570111985}
# Losses {'ner': 7790.181899732495}
# Losses {'ner': 7799.23044762866}
# Losses {'ner': 7887.446742037955}
# Losses {'ner': 7895.611441950116}
# Losses {'ner': 7927.432322203132}
# Losses {'ner': 7986.370130106936}
# Losses {'ner': 8008.423811554743}
# Losses {'ner': 8032.637495542226}
# Losses {'ner': 8081.540755008029}
# Losses {'ner': 8098.876357795615}
# Losses {'ner': 8157.564755282183}
# Losses {'ner': 8271.622390553388}
# Losses {'ner': 8296.021642070396}
# Losses {'ner': 8315.072061929142}
# Losses {'ner': 8334.99897400335}
# Losses {'ner': 8369.874884727908}
# Losses {'ner': 8382.520425521368}
# Losses {'ner': 8395.638883680307}
# Losses {'ner': 8431.525218781002}
# Losses {'ner': 8466.78578266321}
# Losses {'ner': 8494.407117051616}
# Losses {'ner': 8538.268106759127}
# Losses {'ner': 8592.974819620074}
# Losses {'ner': 8639.946069061314}
# Losses {'ner': 8675.402184243036}
# Losses {'ner': 8691.556943487603}
# Losses {'ner': 8728.955033364624}
# Losses {'ner': 8772.787943525056}
# Losses {'ner': 8806.909795141171}
# Losses {'ner': 8859.06113900684}
# Losses {'ner': 8878.124540064284}
# Losses {'ner': 8898.84792999135}
# Losses {'ner': 8960.19675265246}
# Losses {'ner': 9027.958434903976}
# Losses {'ner': 9096.691818647238}
# Losses {'ner': 9145.43081228278}
# Losses {'ner': 9181.557435606905}
# Losses {'ner': 9234.11814600205}
# Losses {'ner': 9247.861748076963}
# Losses {'ner': 9288.881636065864}
# Losses {'ner': 9316.457568299451}
# Losses {'ner': 9412.391814966375}
# Losses {'ner': 9459.235426624758}
# Losses {'ner': 9503.220360840378}
# Losses {'ner': 9573.777260535791}
# Losses {'ner': 9646.286795671605}
# Losses {'ner': 9714.789814612464}
# Losses {'ner': 9836.193359400384}
# Losses {'ner': 9921.627233836904}
# Losses {'ner': 10088.30676678157}
# Losses {'ner': 10274.724310512285}
# Losses {'ner': 10330.311282434497}
# Losses {'ner': 10508.294930686769}
# Losses {'ner': 10530.291258455267}
# Losses {'ner': 10652.715355853381}
# Losses {'ner': 10684.849915196575}
# Losses {'ner': 10750.95834024414}
# Losses {'ner': 10899.557470858428}
# Losses {'ner': 10974.092818706691}
# Losses {'ner': 11083.968173139441}
# Losses {'ner': 11088.098401117055}
# Losses {'ner': 11123.547751766891}
# Losses {'ner': 11123.640015440717}
# Losses {'ner': 11129.53329919976}
# Losses {'ner': 11186.323840365685}
# Losses {'ner': 11211.728566596059}
# Losses {'ner': 11232.20125024059}
# Losses {'ner': 11255.75637850695}
# Losses {'ner': 11280.014273057579}
# Losses {'ner': 11308.081315877202}
# Losses {'ner': 11314.169567745943}
# Losses {'ner': 11378.439085459999}
# Losses {'ner': 11388.885339973911}
# Losses {'ner': 11409.265895120672}
# Losses {'ner': 11480.982961029838}
# Losses {'ner': 11541.343983463086}
# Losses {'ner': 11600.656991101187}
# Losses {'ner': 11604.505414757985}
# Losses {'ner': 11610.275586113965}
# Losses {'ner': 11661.342989799172}
# Losses {'ner': 11680.842502424397}
# Losses {'ner': 11704.863454580474}
# Losses {'ner': 11736.802790487278}
# Losses {'ner': 11780.900708479556}
# Losses {'ner': 11814.664873252132}
# Losses {'ner': 11821.560669058677}
# Losses {'ner': 11832.761661010232}
# Losses {'ner': 11882.486532448916}
# Losses {'ner': 11905.248172119385}
# Losses {'ner': 11922.687469451026}
# Losses {'ner': 11940.226271454036}
# Losses {'ner': 11962.60165704099}
# Losses {'ner': 11987.049648601962}
# Losses {'ner': 12030.330740498555}
# Losses {'ner': 12034.255321623032}
# Losses {'ner': 12038.518571181174}
# Losses {'ner': 12038.635312498016}
# Losses {'ner': 12054.631995594966}
# Losses {'ner': 12096.909558824285}
# Losses {'ner': 12112.157478179832}
# Losses {'ner': 12134.435095871153}
# Losses {'ner': 12150.237643282097}
# Losses {'ner': 12166.086197328847}
# Losses {'ner': 12168.292470738426}
# Losses {'ner': 12168.868751555414}
# Losses {'ner': 12169.625122797352}
# Losses {'ner': 12175.294177621501}
# Losses {'ner': 12183.642427898209}
# Losses {'ner': 12194.38608746287}
# Losses {'ner': 12261.455792745626}
# Losses {'ner': 12289.762946933957}
# Losses {'ner': 12317.181416179084}
# Losses {'ner': 12337.111749583899}
# Losses {'ner': 12360.880948768283}
# Losses {'ner': 12406.524340296224}
# Losses {'ner': 12480.129149877695}
# Losses {'ner': 12528.046310062342}
# Losses {'ner': 12603.010383316798}
# Losses {'ner': 12645.457340349443}
# Losses {'ner': 12718.202847287072}
# Losses {'ner': 12745.728090210223}
# Losses {'ner': 12823.92232329899}
# Losses {'ner': 12877.24862485752}
# Losses {'ner': 12927.994478640776}
# Losses {'ner': 12963.38930690668}
# Losses {'ner': 12982.365455294186}
# Losses {'ner': 13015.88488397827}
# Losses {'ner': 13099.555506476714}
# Losses {'ner': 13121.161000962382}
# Losses {'ner': 13176.373758159563}
# Losses {'ner': 13205.84397271147}
# Losses {'ner': 13263.36367336471}
# Losses {'ner': 13292.102254936835}
# Losses {'ner': 13314.800516248531}
# Losses {'ner': 13407.105159471725}
# Losses {'ner': 13498.727175338938}
# Losses {'ner': 13566.412752175223}
# Losses {'ner': 13591.038067581103}
# Losses {'ner': 13654.108974495182}
# Losses {'ner': 13667.705399153596}
# Losses {'ner': 13689.465658847694}
# Losses {'ner': 13774.055686596568}
# Losses {'ner': 13796.907570374673}
# Losses {'ner': 13812.165434413882}
# Losses {'ner': 13833.8172837737}
# Losses {'ner': 13943.23312794166}
# Losses {'ner': 13956.37674009651}
# Losses {'ner': 13982.432756623935}
# Losses {'ner': 13982.432814939464}
# Losses {'ner': 14012.068942999764}
# Losses {'ner': 14148.536293789974}
# Losses {'ner': 14438.471814930843}
# Losses {'ner': 14509.984753810963}
# Losses {'ner': 14571.599372925113}
# Losses {'ner': 14636.521795178274}
# Losses {'ner': 14683.856873972309}
# Losses {'ner': 14910.297159809972}
# Losses {'ner': 14971.497801621541}
# Losses {'ner': 15020.410183260154}
# Losses {'ner': 15148.50276668748}
# Losses {'ner': 15197.026499254263}
# Losses {'ner': 15258.773162109483}
# Losses {'ner': 15326.203687466252}
# Losses {'ner': 15370.167235143177}
# Losses {'ner': 15415.995268291546}
# Losses {'ner': 15474.533900284821}
# Losses {'ner': 15484.436364016867}
# Losses {'ner': 15518.809698250967}
# Losses {'ner': 15768.008249123568}
# Losses {'ner': 15785.414996830485}
# Losses {'ner': 15888.701801431189}
# Losses {'ner': 15904.863522632326}
# Losses {'ner': 16087.044384714292}
# Losses {'ner': 16139.406538555011}
# Losses {'ner': 16322.657201907912}
# Losses {'ner': 16418.330476152125}
# Losses {'ner': 16507.02481326008}
# Losses {'ner': 16626.052926254553}
# Losses {'ner': 16662.791411344446}
# Losses {'ner': 16697.11137250356}
# Losses {'ner': 16775.823143084028}
# Losses {'ner': 16842.081967333426}
# Losses {'ner': 16886.101150183546}
# Losses {'ner': 16920.359860071338}
# Losses {'ner': 16935.101128003647}
# Losses {'ner': 16962.56077918331}
# Losses {'ner': 17058.146815326087}
# Losses {'ner': 17093.14582233118}
# Losses {'ner': 17126.2590554713}
# Statring iteration 2
# Losses {'ner': 97.04147724103908}
# Losses {'ner': 254.6980658335251}
# Losses {'ner': 370.2357511821201}
# Losses {'ner': 427.2477262305549}
# Losses {'ner': 534.6826122999513}
# Losses {'ner': 566.6072061133734}
# Losses {'ner': 578.6768460523466}
# Losses {'ner': 630.7113809435058}
# Losses {'ner': 732.0164524954798}
# Losses {'ner': 797.7047947478054}
# Losses {'ner': 797.762197763448}
# Losses {'ner': 993.7796712084929}
# Losses {'ner': 1119.1409297248383}
# Losses {'ner': 1191.474595630528}
# Losses {'ner': 1281.6056356855352}
# Losses {'ner': 1372.4349648931748}
# Losses {'ner': 1392.5084597566656}
# Losses {'ner': 1484.142687536262}
# Losses {'ner': 1520.5367931911946}
# Losses {'ner': 1535.172499836012}
# Losses {'ner': 1561.3177797908102}
# Losses {'ner': 1576.8673210561128}
# Losses {'ner': 1628.4303050628087}
# Losses {'ner': 1667.047671503023}
# Losses {'ner': 1712.8552485535718}
# Losses {'ner': 1761.5676381024402}
# Losses {'ner': 1774.511451845867}
# Losses {'ner': 1797.1707226508208}
# Losses {'ner': 1932.4979238788221}
# Losses {'ner': 1950.3874058361287}
# Losses {'ner': 1951.2362375042587}
# Losses {'ner': 1951.7285547672748}
# Losses {'ner': 2001.3094484887745}
# Losses {'ner': 2001.6773964627619}
# Losses {'ner': 2015.3411307452318}
# Losses {'ner': 2038.2799759268473}
# Losses {'ner': 2185.266393287694}
# Losses {'ner': 2231.889217833504}
# Losses {'ner': 2232.2140331245555}
# Losses {'ner': 2266.207538393868}
# Losses {'ner': 2266.507308282675}
# Losses {'ner': 2266.507396119769}
# Losses {'ner': 2275.0458106508904}
# Losses {'ner': 2346.9117497101183}
# Losses {'ner': 2405.6050934096174}
# Losses {'ner': 2420.6751375089734}
# Losses {'ner': 2529.8868389562404}
# Losses {'ner': 2603.5368373599554}
# Losses {'ner': 2748.6529858392105}
# Losses {'ner': 2933.7289652023965}
# Losses {'ner': 2960.3230837707647}
# Losses {'ner': 2985.238864579721}
# Losses {'ner': 3006.7325356925053}
# Losses {'ner': 3120.339039411054}
# Losses {'ner': 3296.9678651209183}
# Losses {'ner': 3404.5441188293294}
# Losses {'ner': 3435.128838654036}
# Losses {'ner': 3512.5647465198886}
# Losses {'ner': 3543.9424700526656}
# Losses {'ner': 3569.7256626713033}
# Losses {'ner': 3658.4389636619353}
# Losses {'ner': 3722.3741439607065}
# Losses {'ner': 3849.489547390472}
# Losses {'ner': 3969.268008975066}
# Losses {'ner': 4048.5149402227403}
# Losses {'ner': 4099.418232414427}
# Losses {'ner': 4166.395004802744}
# Losses {'ner': 4225.548527629285}
# Losses {'ner': 4266.78514083488}
# Losses {'ner': 4320.742582872921}
# Losses {'ner': 4362.943611748089}
# Losses {'ner': 4405.462356102134}
# Losses {'ner': 4467.139071860726}
# Losses {'ner': 4509.55833015343}
# Losses {'ner': 4590.420516940188}
# Losses {'ner': 4673.8589694546945}
# Losses {'ner': 4742.0909183666045}
# Losses {'ner': 4945.09628108266}
# Losses {'ner': 5188.063886771503}
# Losses {'ner': 5299.052392891854}
# Losses {'ner': 5358.0106171440475}
# Losses {'ner': 5409.811624084253}
# Losses {'ner': 5528.492065471246}
# Losses {'ner': 5604.190588345727}
# Losses {'ner': 5657.222716850901}
# Losses {'ner': 5675.998977805212}
# Losses {'ner': 5841.220774784313}
# Losses {'ner': 5890.645569315944}
# Losses {'ner': 5999.38479072043}
# Losses {'ner': 6015.881407728672}
# Losses {'ner': 6027.733054393448}
# Losses {'ner': 6031.509878294259}
# Losses {'ner': 6101.973166927359}
# Losses {'ner': 6105.606236292719}
# Losses {'ner': 6126.078543874648}
# Losses {'ner': 6159.235230042471}
# Losses {'ner': 6187.464160690616}
# Losses {'ner': 6205.416149048917}
# Losses {'ner': 6241.236299379849}
# Losses {'ner': 6251.478910272337}
# Losses {'ner': 6318.055783597794}
# Losses {'ner': 6388.879040566211}
# Losses {'ner': 6411.662732597965}
# Losses {'ner': 6417.714037863562}
# Losses {'ner': 6435.607502241347}
# Losses {'ner': 6459.611883638997}
# Losses {'ner': 6463.645741693365}
# Losses {'ner': 6469.249916214264}
# Losses {'ner': 6495.760752300157}
# Losses {'ner': 6511.9912857818235}
# Losses {'ner': 6529.230278191036}
# Losses {'ner': 6561.355041106898}
# Losses {'ner': 6606.6343898219075}
# Losses {'ner': 6630.93145227299}
# Losses {'ner': 6673.282719404862}
# Losses {'ner': 6683.1831464228035}
# Losses {'ner': 6712.759728117696}
# Losses {'ner': 6746.775919492972}
# Losses {'ner': 6768.7413006940715}
# Losses {'ner': 6801.247769750272}
# Losses {'ner': 6807.757947368118}
# Losses {'ner': 6821.223666476809}
# Losses {'ner': 6870.878869586064}
# Losses {'ner': 6923.502652872368}
# Losses {'ner': 6978.747721180879}
# Losses {'ner': 7001.408469617686}
# Losses {'ner': 7025.486662823595}
# Losses {'ner': 7059.468015218635}
# Losses {'ner': 7063.581706886363}
# Losses {'ner': 7084.955427233071}
# Losses {'ner': 7106.473033990858}
# Losses {'ner': 7178.409853077582}
# Losses {'ner': 7212.978679598068}
# Losses {'ner': 7254.282862663117}
# Losses {'ner': 7324.693870542822}
# Losses {'ner': 7378.105099953808}
# Losses {'ner': 7445.051880711514}
# Losses {'ner': 7580.210999496661}
# Losses {'ner': 7646.747740309698}
# Losses {'ner': 7783.220334568423}
# Losses {'ner': 7946.539973278908}
# Losses {'ner': 8001.631861210035}
# Losses {'ner': 8156.624018117504}
# Losses {'ner': 8171.097192167534}
# Losses {'ner': 8293.23565595892}
# Losses {'ner': 8310.004844790343}
# Losses {'ner': 8355.479443857288}
# Losses {'ner': 8522.768706614454}
# Losses {'ner': 8610.196228024764}
# Losses {'ner': 8688.740417996922}
# Losses {'ner': 8689.142426208984}
# Losses {'ner': 8701.00108309839}
# Losses {'ner': 8702.394153886326}
# Losses {'ner': 8704.495984838517}
# Losses {'ner': 8726.04218057817}
# Losses {'ner': 8743.80310321634}
# Losses {'ner': 8753.147487495547}
# Losses {'ner': 8765.792435110863}
# Losses {'ner': 8773.700318381443}
# Losses {'ner': 8801.490113932487}
# Losses {'ner': 8802.56667469233}
# Losses {'ner': 8840.921455961397}
# Losses {'ner': 8841.980709713012}
# Losses {'ner': 8867.978470466756}
# Losses {'ner': 8919.996658311611}
# Losses {'ner': 8959.095049989015}
# Losses {'ner': 8994.890498955205}
# Losses {'ner': 8998.801388518916}
# Losses {'ner': 9003.416356025653}
# Losses {'ner': 9033.19398326519}
# Losses {'ner': 9039.885609884068}
# Losses {'ner': 9066.899025422143}
# Losses {'ner': 9076.461709817879}
# Losses {'ner': 9111.001058995244}
# Losses {'ner': 9138.943796857626}
# Losses {'ner': 9141.609777315825}
# Losses {'ner': 9150.019551588799}
# Losses {'ner': 9185.070625400542}
# Losses {'ner': 9204.737722647007}
# Losses {'ner': 9223.486365634944}
# Losses {'ner': 9233.802143576359}
# Losses {'ner': 9239.39855253283}
# Losses {'ner': 9267.268247232998}
# Losses {'ner': 9292.066938390391}
# Losses {'ner': 9294.389376132729}
# Losses {'ner': 9299.169917377354}
# Losses {'ner': 9299.170259241988}
# Losses {'ner': 9309.252981481879}
# Losses {'ner': 9340.996169761087}
# Losses {'ner': 9353.057475337942}
# Losses {'ner': 9385.009529576877}
# Losses {'ner': 9394.59539335352}
# Losses {'ner': 9402.025270435528}
# Losses {'ner': 9403.004593731122}
# Losses {'ner': 9404.684768193967}
# Losses {'ner': 9404.695611132855}
# Losses {'ner': 9407.83865811964}
# Losses {'ner': 9412.195524208773}
# Losses {'ner': 9418.587269060645}
# Losses {'ner': 9452.456888134951}
# Losses {'ner': 9467.350863341428}
# Losses {'ner': 9491.770699308205}
# Losses {'ner': 9511.313024430887}
# Losses {'ner': 9526.399899239826}
# Losses {'ner': 9572.875109844728}
# Losses {'ner': 9625.44707361939}
# Losses {'ner': 9642.950343211738}
# Losses {'ner': 9699.346827592302}
# Losses {'ner': 9721.299603580215}
# Losses {'ner': 9784.261418321887}
# Losses {'ner': 9815.202659572114}
# Losses {'ner': 9873.025456926298}
# Losses {'ner': 9912.990836154368}
# Losses {'ner': 9944.929543868268}
# Losses {'ner': 9966.028977922788}
# Losses {'ner': 9981.089797884715}
# Losses {'ner': 10008.46313096691}
# Losses {'ner': 10068.902200683355}
# Losses {'ner': 10083.649433443255}
# Losses {'ner': 10145.968358775744}
# Losses {'ner': 10169.906991128833}
# Losses {'ner': 10203.540242732379}
# Losses {'ner': 10215.64063690634}
# Losses {'ner': 10230.679382425533}
# Losses {'ner': 10286.422920998235}
# Losses {'ner': 10355.25357644572}
# Losses {'ner': 10404.698104690846}
# Losses {'ner': 10432.669943549634}
# Losses {'ner': 10461.659410441298}
# Losses {'ner': 10475.978997058208}
# Losses {'ner': 10490.719924953952}
# Losses {'ner': 10553.519060902445}
# Losses {'ner': 10567.903916149779}
# Losses {'ner': 10585.79478078835}
# Losses {'ner': 10596.44602700092}
# Losses {'ner': 10699.09739317982}
# Losses {'ner': 10704.372705262998}
# Losses {'ner': 10727.199922285987}
# Losses {'ner': 10727.200040807065}
# Losses {'ner': 10758.534283255796}
# Losses {'ner': 10884.715947480941}
# Losses {'ner': 11124.331862982122}
# Losses {'ner': 11195.365217247745}
# Losses {'ner': 11241.269585611639}
# Losses {'ner': 11277.191177684741}
# Losses {'ner': 11305.593179434336}
# Losses {'ner': 11469.873887741382}
# Losses {'ner': 11497.74705808042}
# Losses {'ner': 11538.513847395503}
# Losses {'ner': 11615.773651660393}
# Losses {'ner': 11650.284494420923}
# Losses {'ner': 11680.150594714221}
# Losses {'ner': 11707.651471667317}
# Losses {'ner': 11722.598703233076}
# Losses {'ner': 11775.509991316792}
# Losses {'ner': 11827.181540510208}
# Losses {'ner': 11838.892253322576}
# Losses {'ner': 11860.05456699248}
# Losses {'ner': 12036.838319083721}
# Losses {'ner': 12048.763005059216}
# Losses {'ner': 12124.271412235508}
# Losses {'ner': 12138.332596642145}
# Losses {'ner': 12234.76810509334}
# Losses {'ner': 12270.719168500742}
# Losses {'ner': 12424.051020789075}
# Losses {'ner': 12498.171677552607}
# Losses {'ner': 12537.906998551778}
# Losses {'ner': 12621.815191116148}
# Losses {'ner': 12636.069371361762}
# Losses {'ner': 12663.321198903128}
# Losses {'ner': 12724.261575324297}
# Losses {'ner': 12763.14373735665}
# Losses {'ner': 12791.936212991846}
# Losses {'ner': 12803.512713977947}
# Losses {'ner': 12803.82390113331}
# Losses {'ner': 12830.453402367162}
# Losses {'ner': 12906.116610455467}
# Losses {'ner': 12922.747804274326}
# Losses {'ner': 12937.671397019503}
# Statring iteration 3
# Losses {'ner': 99.98042418560284}
# Losses {'ner': 212.64728755299097}
# Losses {'ner': 302.8946466713076}
# Losses {'ner': 334.62030758156504}
# Losses {'ner': 386.28166774413313}
# Losses {'ner': 407.8377000306012}
# Losses {'ner': 416.53272157056983}
# Losses {'ner': 458.31532022016904}
# Losses {'ner': 523.1634956251972}
# Losses {'ner': 608.050160961248}
# Losses {'ner': 608.0617461516908}
# Losses {'ner': 731.0527279544076}
# Losses {'ner': 848.6032307603706}
# Losses {'ner': 891.6871091309322}
# Losses {'ner': 965.5798515872474}
# Losses {'ner': 1005.9065759913562}
# Losses {'ner': 1015.6768672325611}
# Losses {'ner': 1084.5018500725914}
# Losses {'ner': 1111.0021281162906}
# Losses {'ner': 1113.423536603693}
# Losses {'ner': 1126.2714697507654}
# Losses {'ner': 1147.6797009675108}
# Losses {'ner': 1176.3805309270276}
# Losses {'ner': 1204.2814309524354}
# Losses {'ner': 1255.8798975548789}
# Losses {'ner': 1284.1301811808619}
# Losses {'ner': 1292.524659515178}
# Losses {'ner': 1302.6123052203739}
# Losses {'ner': 1381.8242874759228}
# Losses {'ner': 1382.9907505487547}
# Losses {'ner': 1382.991264014114}
# Losses {'ner': 1383.948193315944}
# Losses {'ner': 1405.9944528899123}
# Losses {'ner': 1406.0148656379506}
# Losses {'ner': 1408.7082970265906}
# Losses {'ner': 1417.9540705392608}
# Losses {'ner': 1535.8669771507764}
# Losses {'ner': 1571.9465342579958}
# Losses {'ner': 1571.9471690302041}
# Losses {'ner': 1600.6056696405192}
# Losses {'ner': 1600.606710405279}
# Losses {'ner': 1600.6067127446074}
# Losses {'ner': 1605.48867582472}
# Losses {'ner': 1657.8455490861782}
# Losses {'ner': 1697.888731462506}
# Losses {'ner': 1712.1284437548668}
# Losses {'ner': 1787.7307149161313}
# Losses {'ner': 1868.9046773471296}
# Losses {'ner': 1986.033642430999}
# Losses {'ner': 2139.005833960179}
# Losses {'ner': 2163.922737897814}
# Losses {'ner': 2171.2980314325837}
# Losses {'ner': 2175.8319547898886}
# Losses {'ner': 2269.6082784829173}
# Losses {'ner': 2403.152233208052}
# Losses {'ner': 2484.1990889040653}
# Losses {'ner': 2501.988915176339}
# Losses {'ner': 2570.8503159806114}
# Losses {'ner': 2591.093642682903}
# Losses {'ner': 2595.823751773709}
# Losses {'ner': 2682.6112885180783}
# Losses {'ner': 2738.719622028256}
# Losses {'ner': 2854.8460416161033}
# Losses {'ner': 2959.8592726450725}
# Losses {'ner': 3041.3109095922173}
# Losses {'ner': 3075.778357753341}
# Losses {'ner': 3122.341969564517}
# Losses {'ner': 3183.498935596924}
# Losses {'ner': 3234.3050156581576}
# Losses {'ner': 3269.355505603849}
# Losses {'ner': 3308.9430046605125}
# Losses {'ner': 3338.6199897351585}
# Losses {'ner': 3390.6426379381805}
# Losses {'ner': 3412.740191212158}
# Losses {'ner': 3459.7192702689777}
# Losses {'ner': 3514.643094693634}
# Losses {'ner': 3568.6036875613204}
# Losses {'ner': 3795.5058595085065}
# Losses {'ner': 4027.7196385116536}
# Losses {'ner': 4101.459649655624}
# Losses {'ner': 4141.569268801143}
# Losses {'ner': 4176.786128912702}
# Losses {'ner': 4247.510331798866}
# Losses {'ner': 4308.335835554536}
# Losses {'ner': 4351.79629442612}
# Losses {'ner': 4363.0099735320855}
# Losses {'ner': 4497.501252093407}
# Losses {'ner': 4537.02993906663}
# Losses {'ner': 4602.1953247327265}
# Losses {'ner': 4614.573064537088}
# Losses {'ner': 4618.273748035665}
# Losses {'ner': 4618.428763370206}
# Losses {'ner': 4680.4859633856195}
# Losses {'ner': 4681.257100227374}
# Losses {'ner': 4690.923962969747}
# Losses {'ner': 4705.499065765604}
# Losses {'ner': 4720.802772883736}
# Losses {'ner': 4751.118111060578}
# Losses {'ner': 4785.37154475887}
# Losses {'ner': 4802.330498899014}
# Losses {'ner': 4852.257870595105}
# Losses {'ner': 4901.138712260856}
# Losses {'ner': 4920.05920043649}
# Losses {'ner': 4922.194865557673}
# Losses {'ner': 4936.129867699466}
# Losses {'ner': 4947.263967579569}
# Losses {'ner': 4949.587054421143}
# Losses {'ner': 4954.695220262151}
# Losses {'ner': 4973.798893867402}
# Losses {'ner': 4981.984819424623}
# Losses {'ner': 4987.987120644786}
# Losses {'ner': 5010.51606604189}
# Losses {'ner': 5048.34532382577}
# Losses {'ner': 5085.245183920661}
# Losses {'ner': 5111.669490962319}
# Losses {'ner': 5118.702278620499}
# Losses {'ner': 5146.126444557542}
# Losses {'ner': 5183.3529844936465}
# Losses {'ner': 5203.384178665903}
# Losses {'ner': 5223.596673980292}
# Losses {'ner': 5231.606337122792}
# Losses {'ner': 5242.041051285384}
# Losses {'ner': 5272.023289344936}
# Losses {'ner': 5338.860314912484}
# Losses {'ner': 5392.99624638411}
# Losses {'ner': 5412.297228194542}
# Losses {'ner': 5432.147513685288}
# Losses {'ner': 5452.1277284193775}
# Losses {'ner': 5455.519896026227}
# Losses {'ner': 5463.314610181439}
# Losses {'ner': 5480.5494453399915}
# Losses {'ner': 5521.3106069881105}
# Losses {'ner': 5546.781824975957}
# Losses {'ner': 5588.81141646703}
# Losses {'ner': 5630.414348741553}
# Losses {'ner': 5676.899202238712}
# Losses {'ner': 5723.743781557922}
# Losses {'ner': 5834.793567405397}
# Losses {'ner': 5876.818308591127}
# Losses {'ner': 6005.03555111987}
# Losses {'ner': 6137.588147491262}
# Losses {'ner': 6171.0473223511935}
# Losses {'ner': 6266.360767801994}
# Losses {'ner': 6270.711356977336}
# Losses {'ner': 6375.944152136489}
# Losses {'ner': 6393.531485483141}
# Losses {'ner': 6430.828588514989}
# Losses {'ner': 6543.124939088264}
# Losses {'ner': 6603.818684041772}
# Losses {'ner': 6633.690425325227}
# Losses {'ner': 6633.9003449550155}
# Losses {'ner': 6643.839370672176}
# Losses {'ner': 6643.839512740667}
# Losses {'ner': 6646.256182431763}
# Losses {'ner': 6648.0227197224585}
# Losses {'ner': 6662.750725289506}
# Losses {'ner': 6669.829722550772}
# Losses {'ner': 6677.1791740203535}
# Losses {'ner': 6684.12713385547}
# Losses {'ner': 6702.174012150976}
# Losses {'ner': 6707.854857012776}
# Losses {'ner': 6778.361408349182}
# Losses {'ner': 6779.537857488191}
# Losses {'ner': 6786.811197499299}
# Losses {'ner': 6831.293754707881}
# Losses {'ner': 6854.263522182353}
# Losses {'ner': 6869.19380110821}
# Losses {'ner': 6870.72999621636}
# Losses {'ner': 6874.588261315106}
# Losses {'ner': 6906.921345723535}
# Losses {'ner': 6908.889339705287}
# Losses {'ner': 6918.875567059961}
# Losses {'ner': 6930.145148966429}
# Losses {'ner': 6951.483570232888}
# Losses {'ner': 6980.4846786381}
# Losses {'ner': 6984.358806351198}
# Losses {'ner': 6993.03336573338}
# Losses {'ner': 7018.045455600452}
# Losses {'ner': 7028.346265570361}
# Losses {'ner': 7054.088660125631}
# Losses {'ner': 7058.026847697183}
# Losses {'ner': 7062.283892830254}
# Losses {'ner': 7086.627163066688}
# Losses {'ner': 7109.409719036646}
# Losses {'ner': 7109.843077592973}
# Losses {'ner': 7113.942091242453}
# Losses {'ner': 7113.942091872133}
# Losses {'ner': 7124.735365295935}
# Losses {'ner': 7150.170808043488}
# Losses {'ner': 7159.747194549811}
# Losses {'ner': 7183.037838007421}
# Losses {'ner': 7184.648656714216}
# Losses {'ner': 7193.140030035207}
# Losses {'ner': 7193.64562604819}
# Losses {'ner': 7193.6490421787075}
# Losses {'ner': 7193.681832451563}
# Losses {'ner': 7194.378762848617}
# Losses {'ner': 7199.151439157939}
# Losses {'ner': 7202.016125487161}
# Losses {'ner': 7232.749369944526}
# Losses {'ner': 7238.963532166718}
# Losses {'ner': 7262.88593481839}
# Losses {'ner': 7275.0990048805625}
# Losses {'ner': 7290.405375473323}
# Losses {'ner': 7321.825804219466}
# Losses {'ner': 7359.25770787661}
# Losses {'ner': 7368.7847327167365}
# Losses {'ner': 7396.348876006176}
# Losses {'ner': 7422.019305813122}
# Losses {'ner': 7478.1548346364125}
# Losses {'ner': 7494.726670068296}
# Losses {'ner': 7542.943811089748}
# Losses {'ner': 7586.909583978816}
# Losses {'ner': 7616.795972270563}
# Losses {'ner': 7635.462076985595}
# Losses {'ner': 7653.946520908723}
# Losses {'ner': 7673.110916043393}
# Losses {'ner': 7716.058641960281}
# Losses {'ner': 7722.713548725703}
# Losses {'ner': 7765.229588334874}
# Losses {'ner': 7781.39999246751}
# Losses {'ner': 7818.610625508084}
# Losses {'ner': 7841.609120393219}
# Losses {'ner': 7863.451341130847}
# Losses {'ner': 7912.011165408775}
# Losses {'ner': 7965.965196730742}
# Losses {'ner': 8041.3439229852}
# Losses {'ner': 8051.4394447642935}
# Losses {'ner': 8065.2191126392345}
# Losses {'ner': 8065.809362938498}
# Losses {'ner': 8071.973524320587}
# Losses {'ner': 8116.876992871885}
# Losses {'ner': 8133.7093738715785}
# Losses {'ner': 8148.573334921151}
# Losses {'ner': 8159.176801297219}
# Losses {'ner': 8242.48593458909}
# Losses {'ner': 8246.103023502685}
# Losses {'ner': 8264.617302190916}
# Losses {'ner': 8264.617479879578}
# Losses {'ner': 8277.579620071836}
# Losses {'ner': 8339.851980942567}
# Losses {'ner': 8445.611194621622}
# Losses {'ner': 8470.060908859265}
# Losses {'ner': 8499.982749613975}
# Losses {'ner': 8539.112303618347}
# Losses {'ner': 8546.810859428651}
# Losses {'ner': 8615.771856048663}
# Losses {'ner': 8639.796588673747}
# Losses {'ner': 8659.04398019003}
# Losses {'ner': 8707.433175228023}
# Losses {'ner': 8744.919244163226}
# Losses {'ner': 8765.30847278312}
# Losses {'ner': 8795.837361199188}
# Losses {'ner': 8804.010149948597}
# Losses {'ner': 8826.320606596817}
# Losses {'ner': 8860.619340237923}
# Losses {'ner': 8870.22468309469}
# Losses {'ner': 8888.310217017599}
# Losses {'ner': 9025.953529995488}
# Losses {'ner': 9030.547759083467}
# Losses {'ner': 9085.448414827384}
# Losses {'ner': 9093.096807884978}
# Losses {'ner': 9161.574039638475}
# Losses {'ner': 9200.376676143193}
# Losses {'ner': 9300.428729803903}
# Losses {'ner': 9368.444010336943}
# Losses {'ner': 9415.750703940945}
# Losses {'ner': 9479.970898255458}
# Losses {'ner': 9510.246484711479}
# Losses {'ner': 9538.652993810801}
# Losses {'ner': 9577.629667342233}
# Losses {'ner': 9610.846337199526}
# Losses {'ner': 9623.115984824935}
# Losses {'ner': 9629.639346825777}
# Losses {'ner': 9634.340712778961}
# Losses {'ner': 9647.510084106096}
# Losses {'ner': 9709.351271022872}
# Losses {'ner': 9727.707117328784}
# Losses {'ner': 9740.163944031301}
# Statring iteration 4
# Losses {'ner': 61.367538258351296}
# Losses {'ner': 133.3967478009814}
# Losses {'ner': 220.3546057003801}
# Losses {'ner': 249.98376969466995}
# Losses {'ner': 291.61568090064713}
# Losses {'ner': 307.866746982876}
# Losses {'ner': 315.9606922599173}
# Losses {'ner': 354.6018612732078}
# Losses {'ner': 408.61691265586427}
# Losses {'ner': 486.98601628744836}
# Losses {'ner': 486.9860203753477}
# Losses {'ner': 626.6909075351418}
# Losses {'ner': 689.4948321594303}
# Losses {'ner': 727.6962957846816}
# Losses {'ner': 787.0981863695959}
# Losses {'ner': 812.0168818653818}
# Losses {'ner': 812.7722467818837}
# Losses {'ner': 851.7039691822073}
# Losses {'ner': 876.4159426686966}
# Losses {'ner': 879.1582592769387}
# Losses {'ner': 895.7287126760338}
# Losses {'ner': 924.6694543041209}
# Losses {'ner': 954.0109133867982}
# Losses {'ner': 977.7097675736369}
# Losses {'ner': 1020.8603812670669}
# Losses {'ner': 1047.8996052531322}
# Losses {'ner': 1049.1821610508725}
# Losses {'ner': 1059.6712264312664}
# Losses {'ner': 1116.565546839187}
# Losses {'ner': 1116.582995631762}
# Losses {'ner': 1116.5831415824616}
# Losses {'ner': 1116.583951910041}
# Losses {'ner': 1126.7013612426654}
# Losses {'ner': 1126.7599957171797}
# Losses {'ner': 1130.1550763411399}
# Losses {'ner': 1145.9289498206908}
# Losses {'ner': 1238.3451407186742}
# Losses {'ner': 1241.5945420858059}
# Losses {'ner': 1241.594720485844}
# Losses {'ner': 1270.3719704128657}
# Losses {'ner': 1270.3719706501524}
# Losses {'ner': 1270.3719707567748}
# Losses {'ner': 1276.3825831306922}
# Losses {'ner': 1298.9235468248603}
# Losses {'ner': 1338.4150136831354}
# Losses {'ner': 1346.6590173188497}
# Losses {'ner': 1420.3310893830283}
# Losses {'ner': 1479.3645231117932}
# Losses {'ner': 1580.1249578093075}
# Losses {'ner': 1729.3769632500123}
# Losses {'ner': 1742.0183503721119}
# Losses {'ner': 1757.385036303359}
# Losses {'ner': 1770.375706042412}
# Losses {'ner': 1859.9599086406163}
# Losses {'ner': 1943.4571643185145}
# Losses {'ner': 2009.096665683092}
# Losses {'ner': 2017.012609607699}
# Losses {'ner': 2075.3622201722437}
# Losses {'ner': 2094.0394378028172}
# Losses {'ner': 2095.3663313369075}
# Losses {'ner': 2180.9942020412827}
# Losses {'ner': 2252.194746684266}
# Losses {'ner': 2335.459296071292}
# Losses {'ner': 2403.546353848043}
# Losses {'ner': 2487.4544534674023}
# Losses {'ner': 2523.1370219314804}
# Losses {'ner': 2560.024715264742}
# Losses {'ner': 2596.0506865231805}
# Losses {'ner': 2618.0982107792242}
# Losses {'ner': 2639.617995518752}
# Losses {'ner': 2659.031381142416}
# Losses {'ner': 2689.2387242347636}
# Losses {'ner': 2727.4038960683774}
# Losses {'ner': 2734.853946638813}
# Losses {'ner': 2792.4054556881333}
# Losses {'ner': 2849.3659760999844}
# Losses {'ner': 2891.9593609939284}
# Losses {'ner': 3107.6881119695063}
# Losses {'ner': 3327.253890132122}
# Losses {'ner': 3389.6878188604037}
# Losses {'ner': 3409.190629565735}
# Losses {'ner': 3446.662266745227}
# Losses {'ner': 3512.9574009296953}
# Losses {'ner': 3569.421637091916}
# Losses {'ner': 3605.488417218432}
# Losses {'ner': 3616.3251104339297}
# Losses {'ner': 3720.852369961212}
# Losses {'ner': 3748.3469210373255}
# Losses {'ner': 3797.6878704073183}
# Losses {'ner': 3803.455160537523}
# Losses {'ner': 3804.4492321503894}
# Losses {'ner': 3804.4680434395686}
# Losses {'ner': 3859.377248306953}
# Losses {'ner': 3863.31803795101}
# Losses {'ner': 3874.7826883708744}
# Losses {'ner': 3886.202060479516}
# Losses {'ner': 3906.26869435227}
# Losses {'ner': 3931.8544037617885}
# Losses {'ner': 3967.865814031047}
# Losses {'ner': 3976.6254269771434}
# Losses {'ner': 4028.0979871040117}
# Losses {'ner': 4069.4442597050165}
# Losses {'ner': 4093.8721730128104}
# Losses {'ner': 4099.570855720352}
# Losses {'ner': 4123.464056440751}
# Losses {'ner': 4137.29969049518}
# Losses {'ner': 4137.66671498228}
# Losses {'ner': 4142.786901258515}
# Losses {'ner': 4155.124839666717}
# Losses {'ner': 4160.637506024558}
# Losses {'ner': 4169.8116523285025}
# Losses {'ner': 4193.229425547977}
# Losses {'ner': 4224.915198677432}
# Losses {'ner': 4243.848032980849}
# Losses {'ner': 4268.083994362194}
# Losses {'ner': 4268.819853526828}
# Losses {'ner': 4277.736964091289}
# Losses {'ner': 4295.260496213582}
# Losses {'ner': 4320.897495299702}
# Losses {'ner': 4343.535655352517}
# Losses {'ner': 4350.959405730608}
# Losses {'ner': 4358.583491247781}
# Losses {'ner': 4400.650108107815}
# Losses {'ner': 4464.73850693997}
# Losses {'ner': 4530.003974549278}
# Losses {'ner': 4536.647113604898}
# Losses {'ner': 4545.197390156942}
# Losses {'ner': 4559.863019621569}
# Losses {'ner': 4561.897049921946}
# Losses {'ner': 4579.022057460269}
# Losses {'ner': 4594.086904913084}
# Losses {'ner': 4628.10218528706}
# Losses {'ner': 4648.989601382467}
# Losses {'ner': 4687.39336787558}
# Losses {'ner': 4744.207021914109}
# Losses {'ner': 4764.800697099985}
# Losses {'ner': 4784.648643336479}
# Losses {'ner': 4843.670009834512}
# Losses {'ner': 4885.507562832347}
# Losses {'ner': 4976.118350229072}
# Losses {'ner': 5094.532082628805}
# Losses {'ner': 5137.5414854614855}
# Losses {'ner': 5233.711695353553}
# Losses {'ner': 5242.945153158995}
# Losses {'ner': 5334.312848995766}
# Losses {'ner': 5361.163404509919}
# Losses {'ner': 5394.169196196641}
# Losses {'ner': 5502.1680150725315}
# Losses {'ner': 5551.213759616942}
# Losses {'ner': 5569.503756420014}
# Losses {'ner': 5569.612480697856}
# Losses {'ner': 5573.028729597625}
# Losses {'ner': 5573.030207348748}
# Losses {'ner': 5573.6745551717295}
# Losses {'ner': 5576.906721371216}
# Losses {'ner': 5584.13872377285}
# Losses {'ner': 5588.343405984872}
# Losses {'ner': 5593.75416211319}
# Losses {'ner': 5598.11815263395}
# Losses {'ner': 5621.592670012778}
# Losses {'ner': 5621.603170517063}
# Losses {'ner': 5648.912675284811}
# Losses {'ner': 5648.942835242136}
# Losses {'ner': 5655.923126565506}
# Losses {'ner': 5671.8975864408885}
# Losses {'ner': 5683.421305901599}
# Losses {'ner': 5695.296335169981}
# Losses {'ner': 5697.290313544731}
# Losses {'ner': 5703.573966205904}
# Losses {'ner': 5720.148505416628}
# Losses {'ner': 5721.113768039967}
# Losses {'ner': 5739.889585484494}
# Losses {'ner': 5759.858152361263}
# Losses {'ner': 5769.460816053639}
# Losses {'ner': 5803.107058498425}
# Losses {'ner': 5804.427217930034}
# Losses {'ner': 5808.491862174697}
# Losses {'ner': 5837.080117994263}
# Losses {'ner': 5857.35227823214}
# Losses {'ner': 5876.503520926812}
# Losses {'ner': 5878.766348107336}
# Losses {'ner': 5880.7984826515585}
# Losses {'ner': 5900.517171280885}
# Losses {'ner': 5920.69067483158}
# Losses {'ner': 5921.127309593798}
# Losses {'ner': 5921.286336658728}
# Losses {'ner': 5921.286435507815}
# Losses {'ner': 5931.3746306353405}
# Losses {'ner': 5954.223451933198}
# Losses {'ner': 5955.431201602677}
# Losses {'ner': 5971.019603185346}
# Losses {'ner': 5977.080856328201}
# Losses {'ner': 5979.270686138522}
# Losses {'ner': 5979.557277729483}
# Losses {'ner': 5981.373351714736}
# Losses {'ner': 5981.387545159479}
# Losses {'ner': 5981.391591885476}
# Losses {'ner': 5987.087070499693}
# Losses {'ner': 6005.992453973457}
# Losses {'ner': 6033.13891456947}
# Losses {'ner': 6035.98324266932}
# Losses {'ner': 6059.233665721638}
# Losses {'ner': 6069.378578044429}
# Losses {'ner': 6090.181502884712}
# Losses {'ner': 6132.778209552536}
# Losses {'ner': 6171.080102922872}
# Losses {'ner': 6179.884270443838}
# Losses {'ner': 6228.513635774825}
# Losses {'ner': 6247.162138287736}
# Losses {'ner': 6272.887262913881}
# Losses {'ner': 6285.616607931387}
# Losses {'ner': 6322.2706471944875}
# Losses {'ner': 6363.32529423208}
# Losses {'ner': 6391.91974464238}
# Losses {'ner': 6411.825224900669}
# Losses {'ner': 6426.925632639927}
# Losses {'ner': 6447.479555091046}
# Losses {'ner': 6481.438652323048}
# Losses {'ner': 6496.215902334107}
# Losses {'ner': 6526.25497791228}
# Losses {'ner': 6544.325711656781}
# Losses {'ner': 6579.686781984428}
# Losses {'ner': 6600.197435545057}
# Losses {'ner': 6613.206909908462}
# Losses {'ner': 6665.569814660668}
# Losses {'ner': 6707.580510861666}
# Losses {'ner': 6753.352383475075}
# Losses {'ner': 6764.7671578895715}
# Losses {'ner': 6771.227692639072}
# Losses {'ner': 6771.228452463744}
# Losses {'ner': 6786.203840656543}
# Losses {'ner': 6826.43520606156}
# Losses {'ner': 6837.086922769445}
# Losses {'ner': 6849.218227866277}
# Losses {'ner': 6859.417162106791}
# Losses {'ner': 6905.596613740456}
# Losses {'ner': 6905.70800454163}
# Losses {'ner': 6919.988601681655}
# Losses {'ner': 6919.988602876013}
# Losses {'ner': 6934.799023811112}
# Losses {'ner': 7006.240715039399}
# Losses {'ner': 7124.1453396582065}
# Losses {'ner': 7164.845743089547}
# Losses {'ner': 7195.924184541725}
# Losses {'ner': 7224.36365359534}
# Losses {'ner': 7246.556895204282}
# Losses {'ner': 7319.014997727217}
# Losses {'ner': 7326.653561638411}
# Losses {'ner': 7341.318970652784}
# Losses {'ner': 7371.648852490265}
# Losses {'ner': 7397.83202776055}
# Losses {'ner': 7420.648445404894}
# Losses {'ner': 7440.826824105235}
# Losses {'ner': 7446.979381643438}
# Losses {'ner': 7458.531545350136}
# Losses {'ner': 7478.900789859857}
# Losses {'ner': 7484.979584575554}
# Losses {'ner': 7495.906843966314}
# Losses {'ner': 7588.338719818721}
# Losses {'ner': 7595.603349243418}
# Losses {'ner': 7620.5205206760065}
# Losses {'ner': 7624.437871764382}
# Losses {'ner': 7655.420314647896}
# Losses {'ner': 7695.017426150436}
# Losses {'ner': 7777.676754858136}
# Losses {'ner': 7814.6828739317725}
# Losses {'ner': 7830.697002332272}
# Losses {'ner': 7870.94773611184}
# Losses {'ner': 7882.63075292169}
# Losses {'ner': 7896.9486087280375}
# Losses {'ner': 7929.146877760654}
# Losses {'ner': 7948.474751384795}
# Losses {'ner': 7963.2948803597665}
# Losses {'ner': 7967.181590037686}
# Losses {'ner': 7967.820884691061}
# Losses {'ner': 7975.620469673006}
# Losses {'ner': 8023.141573436396}
# Losses {'ner': 8038.698855013465}
# Losses {'ner': 8048.7834022996585}
# Statring iteration 5
# ...
# Losses {'ner': 1232.3023817840701}
# Losses {'ner': 1246.304693052356}
# Losses {'ner': 1248.317078818125}
# Losses {'ner': 1287.1118387223332}
# Losses {'ner': 1313.2118604641746}
# Losses {'ner': 1337.846307322278}
# Losses {'ner': 1337.852943639148}
# Losses {'ner': 1340.2413504808865}
# Losses {'ner': 1346.2491242377741}
# Losses {'ner': 1346.614738374923}
# Losses {'ner': 1347.0787741470665}
# Losses {'ner': 1354.3195453021528}
# Losses {'ner': 1357.1297663047476}
# Losses {'ner': 1357.7683705351108}
# Losses {'ner': 1367.633335837397}
# Losses {'ner': 1399.5887822577276}
# Losses {'ner': 1410.6616974539043}
# Losses {'ner': 1416.299667795377}
# Losses {'ner': 1416.3364529217674}
# Losses {'ner': 1419.8550341770394}
# Losses {'ner': 1423.3887027472251}
# Losses {'ner': 1434.4721049607701}
# Losses {'ner': 1444.0719528480734}
# Losses {'ner': 1444.1850799910837}
# Losses {'ner': 1444.1851495913077}
# Losses {'ner': 1473.7996639121702}
# Losses {'ner': 1523.8362102239241}
# Losses {'ner': 1551.8552240635327}
# Losses {'ner': 1555.8478563169945}
# Losses {'ner': 1557.8748310149765}
# Losses {'ner': 1557.8851329711401}
# Losses {'ner': 1557.8855929436277}
# Losses {'ner': 1562.4533535545474}
# Losses {'ner': 1569.9381384604994}
# Losses {'ner': 1572.2548747447368}
# Losses {'ner': 1585.5771121249365}
# Losses {'ner': 1598.7418922632983}
# Losses {'ner': 1599.1855900761602}
# Losses {'ner': 1603.358783423477}
# Losses {'ner': 1608.480125700418}
# Losses {'ner': 1624.3620624135983}
# Losses {'ner': 1625.851653162264}
# Losses {'ner': 1645.1644737022248}
# Losses {'ner': 1666.058255655349}
# Losses {'ner': 1679.7937926427878}
# Losses {'ner': 1723.3135407488264}
# Losses {'ner': 1724.384419909453}
# Losses {'ner': 1725.7668127444163}
# Losses {'ner': 1728.2457330333211}
# Losses {'ner': 1739.5572921357111}
# Losses {'ner': 1767.462685996804}
# Losses {'ner': 1786.7875003585943}
# Losses {'ner': 1794.3897373719321}
# Losses {'ner': 1794.3898160213141}
# Losses {'ner': 1794.3993536963737}
# Losses {'ner': 1794.403870625927}
# Losses {'ner': 1794.4192283881446}
# Losses {'ner': 1798.0419986818415}
# Losses {'ner': 1799.9121643897279}
# Losses {'ner': 1801.2196382516688}
# Losses {'ner': 1802.7128210886108}
# Losses {'ner': 1802.7138093146953}
# Losses {'ner': 1811.6804208457986}
# Losses {'ner': 1811.884418372386}
# Losses {'ner': 1813.5192556695226}
# Losses {'ner': 1813.5192793783613}
# Losses {'ner': 1813.5976753770676}
# Losses {'ner': 1814.5881927498722}
# Losses {'ner': 1821.8103282285513}
# Losses {'ner': 1821.8170737140083}
# Losses {'ner': 1821.817224238965}
# Losses {'ner': 1821.8172243050876}
# Losses {'ner': 1829.6221632156964}
# Losses {'ner': 1830.5457947719424}
# Losses {'ner': 1830.5458580630334}
# Losses {'ner': 1832.5633778422475}
# Losses {'ner': 1833.700504230852}
# Losses {'ner': 1835.7219639613359}
# Losses {'ner': 1836.6583955193717}
# Losses {'ner': 1840.4684873256117}
# Losses {'ner': 1868.61597534477}
# Losses {'ner': 1877.1196083169516}
# Losses {'ner': 1891.1274146126746}
# Losses {'ner': 1891.7461784740642}
# Losses {'ner': 1894.2464664155023}
# Losses {'ner': 1895.2172545488802}
# Losses {'ner': 1903.5052991738294}
# Losses {'ner': 1903.5091920398213}
# Losses {'ner': 1903.518004779764}
# Losses {'ner': 1903.5184795557238}
# Losses {'ner': 1903.5279069558674}
# Losses {'ner': 1905.9821386664082}
# Losses {'ner': 1906.0450588730043}
# Losses {'ner': 1918.3763184929676}
# Losses {'ner': 1920.2163191160125}
# Losses {'ner': 1920.2164645770172}
# Losses {'ner': 1920.2164658351085}
# Losses {'ner': 1920.2164709954593}
# Losses {'ner': 1921.4325390646322}
# Losses {'ner': 1921.4413194705212}
# Losses {'ner': 1921.4441552253497}
# Losses {'ner': 1925.1960928142637}
# Losses {'ner': 1937.5241354956531}
# Losses {'ner': 1939.8463727345013}
# Losses {'ner': 1949.2029857001023}
# Losses {'ner': 1957.8782274145954}
# Losses {'ner': 1975.2300161347348}
# Losses {'ner': 2004.4393967451106}
# Losses {'ner': 2020.632977205234}
# Losses {'ner': 2021.5209541469249}
# Losses {'ner': 2023.2893434636915}
# Losses {'ner': 2026.4832994017786}
# Losses {'ner': 2027.6858658617314}
# Losses {'ner': 2028.9878520451484}
# Losses {'ner': 2060.469582545844}
# Losses {'ner': 2070.7147723082617}
# Losses {'ner': 2071.506069703103}
# Losses {'ner': 2071.5234597635103}
# Losses {'ner': 2080.9082230188433}
# Losses {'ner': 2082.7758937390245}
# Losses {'ner': 2094.747489923205}
# Losses {'ner': 2095.0241132193014}
# Losses {'ner': 2110.9352001038806}
# Losses {'ner': 2121.063201566356}
# Losses {'ner': 2123.242412814212}
# Losses {'ner': 2127.4926253805265}
# Losses {'ner': 2130.218840193404}
# Losses {'ner': 2131.793313171446}
# Losses {'ner': 2135.712316455544}
# Losses {'ner': 2146.8887558105303}
# Losses {'ner': 2147.5868899377883}
# Losses {'ner': 2150.8382017543395}
# Losses {'ner': 2150.935600835346}
# Losses {'ner': 2151.27416858787}
# Losses {'ner': 2153.3336115395196}
# Losses {'ner': 2156.5221710297324}
# Losses {'ner': 2158.6333270732184}
# Losses {'ner': 2161.441228430973}
# Losses {'ner': 2178.5955822162873}
# Losses {'ner': 2178.697403789216}
# Losses {'ner': 2182.8677655208053}
# Losses {'ner': 2182.8677655464376}
# Losses {'ner': 2185.9010330526403}
# Losses {'ner': 2186.9944871351713}
# Losses {'ner': 2204.7466724443307}
# Losses {'ner': 2210.5744107306696}
# Losses {'ner': 2212.6622173231626}
# Losses {'ner': 2224.205411299427}
# Losses {'ner': 2224.209924406283}
# Losses {'ner': 2238.846735111269}
# Losses {'ner': 2241.7762758479985}
# Losses {'ner': 2242.566200840182}
# Losses {'ner': 2256.8707016895696}
# Losses {'ner': 2264.375685253374}
# Losses {'ner': 2267.2424127263075}
# Losses {'ner': 2270.601065963007}
# Losses {'ner': 2270.6249106024106}
# Losses {'ner': 2270.625541307929}
# Losses {'ner': 2275.0026881819867}
# Losses {'ner': 2277.499070089422}
# Losses {'ner': 2282.269578744241}
# Losses {'ner': 2306.3337288056186}
# Losses {'ner': 2306.3337406065307}
# Losses {'ner': 2310.688223735072}
# Losses {'ner': 2310.8277348850334}
# Losses {'ner': 2316.993567629458}
# Losses {'ner': 2330.5167143236185}
# Losses {'ner': 2344.829321733596}
# Losses {'ner': 2351.9607935849062}
# Losses {'ner': 2360.527632382076}
# Losses {'ner': 2362.515240322228}
# Losses {'ner': 2365.529258621489}
# Losses {'ner': 2365.597885620737}
# Losses {'ner': 2379.3175791706776}
# Losses {'ner': 2387.238834107513}
# Losses {'ner': 2387.372387929795}
# Losses {'ner': 2387.3937663859665}
# Losses {'ner': 2387.3938061907907}
# Losses {'ner': 2391.3581068124495}
# Losses {'ner': 2421.3473076758487}
# Losses {'ner': 2423.409180308695}
# Losses {'ner': 2430.366153422323}
# Statring iteration 19
# Losses {'ner': 15.10189939795777}
# Losses {'ner': 23.410395185667376}
# Losses {'ner': 35.80053191006676}
# Losses {'ner': 40.83755133317853}
# Losses {'ner': 48.44405471926652}
# Losses {'ner': 51.66761431432812}
# Losses {'ner': 61.843977775879175}
# Losses {'ner': 68.46242352378351}
# Losses {'ner': 78.39993959369951}
# Losses {'ner': 88.98067879507616}
# Losses {'ner': 88.98067882894784}
# Losses {'ner': 101.66492941550877}
# Losses {'ner': 124.53581282611441}
# Losses {'ner': 133.9337287640812}
# Losses {'ner': 152.1111667588764}
# Losses {'ner': 154.28683707111415}
# Losses {'ner': 154.28717554693532}
# Losses {'ner': 158.79530706806636}
# Losses {'ner': 180.01498642237968}
# Losses {'ner': 181.23302040742666}
# Losses {'ner': 184.20977779391677}
# Losses {'ner': 184.4896060145776}
# Losses {'ner': 203.31896899812583}
# Losses {'ner': 207.26377343375285}
# Losses {'ner': 214.62518425184916}
# Losses {'ner': 221.10785192552734}
# Losses {'ner': 222.66649393838927}
# Losses {'ner': 223.97382537326988}
# Losses {'ner': 232.75956678964286}
# Losses {'ner': 232.7635207831429}
# Losses {'ner': 232.7635302774881}
# Losses {'ner': 232.76353064439107}
# Losses {'ner': 233.4901784901145}
# Losses {'ner': 233.76070591928425}
# Losses {'ner': 240.78491939078364}
# Losses {'ner': 251.71581939586335}
# Losses {'ner': 270.8485274148356}
# Losses {'ner': 271.9365219924323}
# Losses {'ner': 271.93652199653906}
# Losses {'ner': 277.9544376131564}
# Losses {'ner': 277.96127403172403}
# Losses {'ner': 277.96172267059177}
# Losses {'ner': 278.1933224059592}
# Losses {'ner': 278.22479085932804}
# Losses {'ner': 281.12220506139397}
# Losses {'ner': 281.1227906109145}
# Losses {'ner': 286.9126543426963}
# Losses {'ner': 286.9849480654985}
# Losses {'ner': 328.4104655405063}
# Losses {'ner': 464.5810255959422}
# Losses {'ner': 464.5952472493408}
# Losses {'ner': 468.34036564797134}
# Losses {'ner': 470.3717668734474}
# Losses {'ner': 496.97720681022196}
# Losses {'ner': 524.7091827918181}
# Losses {'ner': 537.062353642603}
# Losses {'ner': 537.0629791778865}
# Losses {'ner': 552.4808065587205}
# Losses {'ner': 564.3399256151713}
# Losses {'ner': 564.3405748201208}
# Losses {'ner': 595.7902471048199}
# Losses {'ner': 634.5457977057382}
# Losses {'ner': 651.5144693871885}
# Losses {'ner': 665.4370535283999}
# Losses {'ner': 702.6360404510306}
# Losses {'ner': 719.8921486303533}
# Losses {'ner': 728.1717803838739}
# Losses {'ner': 731.6527672190578}
# Losses {'ner': 746.4222995327559}
# Losses {'ner': 749.1052075763033}
# Losses {'ner': 756.426139739411}
# Losses {'ner': 760.8868837873595}
# Losses {'ner': 765.3804442618579}
# Losses {'ner': 765.7315435020672}
# Losses {'ner': 777.1586862505068}
# Losses {'ner': 788.2679624459527}
# Losses {'ner': 796.1141804676083}
# Losses {'ner': 920.4936218990022}
# Losses {'ner': 981.2339360774897}
# Losses {'ner': 1010.3503540122557}
# Losses {'ner': 1011.2623899050603}
# Losses {'ner': 1019.1168097568724}
# Losses {'ner': 1046.720201437177}
# Losses {'ner': 1058.9299878315917}
# Losses {'ner': 1071.8834461456315}
# Losses {'ner': 1080.0573325301964}
# Losses {'ner': 1089.2590975142145}
# Losses {'ner': 1104.4194526648773}
# Losses {'ner': 1115.0091138806522}
# Losses {'ner': 1115.012841139433}
# Losses {'ner': 1115.0144954782238}
# Losses {'ner': 1115.024617966378}
# Losses {'ner': 1146.5073487232041}
# Losses {'ner': 1146.5853526326605}
# Losses {'ner': 1148.941891916171}
# Losses {'ner': 1152.2583193083758}
# Losses {'ner': 1156.701077450353}
# Losses {'ner': 1173.9554981823303}
# Losses {'ner': 1187.753200100452}
# Losses {'ner': 1187.7792168795884}
# Losses {'ner': 1231.1144454567047}
# Losses {'ner': 1268.0068976397515}
# Losses {'ner': 1294.2669997000723}
# Losses {'ner': 1294.2701847888973}
# Losses {'ner': 1297.5975578842645}
# Losses {'ner': 1300.6559447567192}
# Losses {'ner': 1300.6576014661186}
# Losses {'ner': 1300.659116412277}
# Losses {'ner': 1305.2878378108155}
# Losses {'ner': 1305.3007469825172}
# Losses {'ner': 1305.3013323058224}
# Losses {'ner': 1308.337501529992}
# Losses {'ner': 1336.1789419861598}
# Losses {'ner': 1342.0736374342123}
# Losses {'ner': 1347.238193491237}
# Losses {'ner': 1350.111815988805}
# Losses {'ner': 1351.7489663423526}
# Losses {'ner': 1355.5997749524977}
# Losses {'ner': 1366.3980613629212}
# Losses {'ner': 1377.5148720145228}
# Losses {'ner': 1377.5336601749593}
# Losses {'ner': 1377.5353192337354}
# Losses {'ner': 1412.4863608767532}
# Losses {'ner': 1449.6423635661963}
# Losses {'ner': 1471.1661605594873}
# Losses {'ner': 1472.5385060633512}
# Losses {'ner': 1474.194932722799}
# Losses {'ner': 1476.2120318060558}
# Losses {'ner': 1476.2122441012327}
# Losses {'ner': 1477.919877431383}
# Losses {'ner': 1489.3808993543057}
# Losses {'ner': 1495.594668354937}
# Losses {'ner': 1517.6274362383235}
# Losses {'ner': 1529.5917794841696}
# Losses {'ner': 1529.8236196034638}
# Losses {'ner': 1535.8803761569402}
# Losses {'ner': 1537.4552549950504}
# Losses {'ner': 1544.8268250767503}
# Losses {'ner': 1548.7464233855255}
# Losses {'ner': 1563.9048712496217}
# Losses {'ner': 1584.1658034437787}
# Losses {'ner': 1596.3496748887958}
# Losses {'ner': 1644.430518647487}
# Losses {'ner': 1644.438778252733}
# Losses {'ner': 1652.7026148428872}
# Losses {'ner': 1654.3450380011861}
# Losses {'ner': 1662.340609688059}
# Losses {'ner': 1688.684078920595}
# Losses {'ner': 1699.8844941169439}
# Losses {'ner': 1705.3988552409526}
# Losses {'ner': 1705.3988581345197}
# Losses {'ner': 1705.4019716107136}
# Losses {'ner': 1705.4019716345608}
# Losses {'ner': 1705.4019991515827}
# Losses {'ner': 1705.5784223828268}
# Losses {'ner': 1706.9390510664998}
# Losses {'ner': 1710.9607235984306}
# Losses {'ner': 1710.9640662372035}
# Losses {'ner': 1711.9643333834204}
# Losses {'ner': 1718.0158329061194}
# Losses {'ner': 1718.0161494042638}
# Losses {'ner': 1721.6276586861277}
# Losses {'ner': 1722.7567728037213}
# Losses {'ner': 1727.4996187868487}
# Losses {'ner': 1727.5686988340556}
# Losses {'ner': 1733.7136873474408}
# Losses {'ner': 1734.5669259642957}
# Losses {'ner': 1736.5491018176738}
# Losses {'ner': 1736.549106618807}
# Losses {'ner': 1736.6328140907838}
# Losses {'ner': 1740.6329669320908}
# Losses {'ner': 1741.7085670434294}
# Losses {'ner': 1741.7570355905527}
# Losses {'ner': 1741.7896025587968}
# Losses {'ner': 1741.7969495836912}
# Losses {'ner': 1741.8840840523953}
# Losses {'ner': 1741.904301255108}
# Losses {'ner': 1763.8543262836238}
# Losses {'ner': 1772.2635944861026}
# Losses {'ner': 1784.1990045214482}
# Losses {'ner': 1784.2109672483361}
# Losses {'ner': 1784.4665228923345}
# Losses {'ner': 1787.070072002353}
# Losses {'ner': 1797.7219854281134}
# Losses {'ner': 1797.7553292960413}
# Losses {'ner': 1797.7716204396374}
# Losses {'ner': 1797.7716451671188}
# Losses {'ner': 1801.770104419793}
# Losses {'ner': 1811.0520650205158}
# Losses {'ner': 1811.0631261008718}
# Losses {'ner': 1825.542574839994}
# Losses {'ner': 1826.0735175350055}
# Losses {'ner': 1826.0740119632383}
# Losses {'ner': 1826.0784654231986}
# Losses {'ner': 1826.0784717164888}
# Losses {'ner': 1826.0784834972517}
# Losses {'ner': 1826.0784843985443}
# Losses {'ner': 1826.0784855275106}
# Losses {'ner': 1826.087461349909}
# Losses {'ner': 1842.0708160002632}
# Losses {'ner': 1848.3532463222593}
# Losses {'ner': 1857.449852432552}
# Losses {'ner': 1861.9874730553695}
# Losses {'ner': 1879.290798207112}
# Losses {'ner': 1907.7907947477352}
# Losses {'ner': 1911.6030442907615}
# Losses {'ner': 1912.2449543254518}
# Losses {'ner': 1913.267080488073}
# Losses {'ner': 1914.426213781604}
# Losses {'ner': 1915.8582082255434}
# Losses {'ner': 1917.2659558285459}
# Losses {'ner': 1971.3739011453426}
# Losses {'ner': 1996.041460519996}
# Losses {'ner': 2001.0335945372099}
# Losses {'ner': 2001.070544616171}
# Losses {'ner': 2010.6789182523553}
# Losses {'ner': 2010.6800503982588}
# Losses {'ner': 2021.8584140414187}
# Losses {'ner': 2021.8714176925378}
# Losses {'ner': 2038.8704122575525}
# Losses {'ner': 2039.094283143192}
# Losses {'ner': 2042.2450641067867}
# Losses {'ner': 2043.874815435095}
# Losses {'ner': 2047.3187978198634}
# Losses {'ner': 2051.080217992865}
# Losses {'ner': 2060.1455758097914}
# Losses {'ner': 2067.004469391548}
# Losses {'ner': 2074.916217148214}
# Losses {'ner': 2080.5371573162715}
# Losses {'ner': 2080.5375101824156}
# Losses {'ner': 2085.3323265570016}
# Losses {'ner': 2093.8833563484823}
# Losses {'ner': 2094.309690684694}
# Losses {'ner': 2096.036041790929}
# Losses {'ner': 2096.0363105853053}
# Losses {'ner': 2101.4794377806115}
# Losses {'ner': 2101.5317715031474}
# Losses {'ner': 2104.673789833828}
# Losses {'ner': 2104.6737898339065}
# Losses {'ner': 2106.6661064533023}
# Losses {'ner': 2107.8360574561048}
# Losses {'ner': 2114.990337197445}
# Losses {'ner': 2118.117756642572}
# Losses {'ner': 2120.185949602449}
# Losses {'ner': 2140.2400690331997}
# Losses {'ner': 2143.2078007587875}
# Losses {'ner': 2175.1755808791186}
# Losses {'ner': 2175.1780782643937}
# Losses {'ner': 2176.346484547231}
# Losses {'ner': 2185.761190676196}
# Losses {'ner': 2192.10033402027}
# Losses {'ner': 2195.8619842717985}
# Losses {'ner': 2201.938811023505}
# Losses {'ner': 2204.176861517867}
# Losses {'ner': 2205.4719740498185}
# Losses {'ner': 2218.923399198138}
# Losses {'ner': 2227.5280735823103}
# Losses {'ner': 2229.732644173395}
# Losses {'ner': 2247.1025860099885}
# Losses {'ner': 2247.1026668161244}
# Losses {'ner': 2254.2228264435657}
# Losses {'ner': 2254.2250686316183}
# Losses {'ner': 2280.0813582270825}
# Losses {'ner': 2288.368173994079}
# Losses {'ner': 2306.477256851944}
# Losses {'ner': 2313.2380194096995}
# Losses {'ner': 2320.093090378656}
# Losses {'ner': 2325.0650939047123}
# Losses {'ner': 2325.082388116865}
# Losses {'ner': 2330.794153349265}
# Losses {'ner': 2336.4720991634917}
# Losses {'ner': 2342.0272794386597}
# Losses {'ner': 2347.6472238366823}
# Losses {'ner': 2347.8903907068034}
# Losses {'ner': 2348.144778657583}
# Losses {'ner': 2350.185525567894}
# Losses {'ner': 2362.423290663732}
# Losses {'ner': 2362.7224083258166}
# Losses {'ner': 2364.3139685030696}

# %% [markdown]
# ### <span style="color:#FF00FF">Model Evaluation</span>

# %%
TEST_DATA = df[['clean_description','tags']].sample(frac=1).reset_index(drop=True)

# %%
def get_predvalues(pred,text):
    res = "O"
    for i in pred:
        if i[1] == text:
            res = "B-"+i[2]
    return res

test = []
for i, j in TEST_DATA.iterrows():
    annots = ast.literal_eval(j[1])
    text   = j[0]
    pred = []    
    doc = jdnlp(text)
    for ent in doc.ents:
        pred.append((i,ent.text, ent.label_))
        
        
    for k in annots.get('entities'):
        st, ed = k[0],k[1]
        txt = text[st:ed]
        tag = get_predvalues(pred,txt)
        test.append((i,txt,"B-"+k[2],tag))

# %%
cols = ["sentence_id","text","actual","pred"]
tdf = pd.DataFrame(test,columns=cols)

y_test = tdf["actual"].tolist()
y_pred = tdf["pred"].tolist()

y_test = [[ind] for ind in y_test]
y_pred = [[ind] for ind in y_pred]

# %%
accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test,y_pred) 
recall =  recall_score(y_test,y_pred)
f1score = f1_score(y_test,y_pred)

SPACY_metrics = {
    "F1-score" : f1score,
    "Accuracy" : accuracy,
    "Precision" : precision,
    "Recall" : recall
}
print(SPACY_metrics)
# Out:
# {'F1-score': 0.9809441731303264, 'Accuracy': 0.9626914763650033, 'Precision': 0.9999023914104441, 'Recall': 0.9626914763650033}

# %% [markdown]
# ### <span style="color:#FF00FF">Classification report</span>

# %%
class_report = classification_report(y_test,y_pred, digits=4)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#         DEPT     1.0000    0.9374    0.9677      2748
#         ROLE     0.9995    0.9781    0.9887      1965
#        SKILL     1.0000    0.9693    0.9844      5928
#
#    micro avg     0.9999    0.9627    0.9809     10641
#    macro avg     0.9998    0.9616    0.9803     10641
# weighted avg     0.9999    0.9627    0.9809     10641

# %% [markdown]
# ### <span style="color:#FF00FF">Save Model and metrics</span>

# %%
SPACY_objects = {
    "spacy_metrics" : SPACY_metrics,
    "spacy_model" : jdnlp
}

pickle_out = open( "../models/SPACY_objects.pkl", "wb" )
pickle.dump(SPACY_objects, pickle_out)

# %% [markdown]
# ### <span style="color:#FF00FF">Load Model and Test</span>

# %%
pickle_in = open("../models/SPACY_objects.pkl", "rb" )
SPACY_obj = pickle.load(pickle_in)

# %% [markdown]
# ### <span style="color:#FF00FF">Predict on new JD</span>

# %%
jdnlp = SPACY_obj.get("spacy_model")

# Testing the model
JD = """description scope role piramal pharma solutions pps chief information officer cio role provide vision leadership developing implementing information technology initiatives align vision piramal pharma solutions pps businesses pps cio charter build competitive edge business proactively building world class high quality innovative technology digital analytics solutions global operations job overview strategy innovation strategic business partner create enhanced digital technology vision enterprise identify opportunities differentiated technology capabilities solutions p roactively recommend solutions business functional leadership team considering business vision industry trends bringing outside perspective p ush bar technology innovation imbibing cutting edge technological innovations global benchmarks blue sky thinking create user friendly technologies offering great experience cts champion change agent accelerating organizational changes required create sustain enterprise technology capabilities cts thought leader emerging digital business models technologies articulating digital future enterprise role internally externally enable business growth enable inorganic business growth merger acquisition leading due diligence driving integration post acquisition lead strategic operational planning implementation achieve business goals fostering innovation prioritizing initiatives coordinating evaluation deployment management current future systems across organization coordinate facilitate consultation relevant business stakeholders define business systems requirements new technology implementations planning execution partner various site ho teams manage project portfolio relate selection acquisition development implementation major information systems defines governance mechanism metrics review progress technology projects business case achievement technology budget company provide upfront estimates costs various heads keep track spends ensure best roi company technology investment maintaining balance frugality financial discipline adequately gearing future growth b uild ecosystem group technology teams partners including startups product vendors develop implement technology solutions b uild future read technology team attracting retaining upskilling industry best talent compliance information security collaborate piramal quality e compliance qec team ensure quality compliance per defined sops guidelines accordance 21 cfr part 11 gamp guidelines collaborate information security team ensure adherence information security guidelines processes skills abilities exceptional inter personal skills enabling engagement levels across leadership skills including ability manage large team understanding strategy business technology application levels environment priorities goals quickly change evolve also skills think strategically including developing information security strategies interpreting handling complex information acting political sensitivity driving engaging positively change sound understanding portfolio program project management track record delivering enabling large scale complex change programs qualifications experience delivering strategy delivery essential across multiple organisations desirable experience working pharma business senior position essential experience procuring managing large complex outcome based contracts interdependencies experience working senior management team develop business focussed strategies effectively support business needs experience technologies sap salesforce bi pharma quality applications preferred experience digital technologies ar vr rpa chatbots ai ml etc preferred experience joint procurement market testing outsourcing well negotiating quality cost effective services experience successfully implementing strategy business planning evidence delivering high quality customer focussed services experience contributing development implementation effective management information systems aid decision making process evidence contribution major transformation building teams time change"""

doc = jdnlp(JD)
print("Entities", set([(ent.text, ent.label_) for ent in doc.ents]))

colors = {"SKILL":"#FFF380","ROLE":"#8EEBEC","DEPT":"#E7A1B0"}
options = {'ents': ['SKILL', 'ROLE','DEPT'], 'colors':colors}
displacy.render(doc,style='ent',jupyter=True, options=options)
# Out:
# Entities {('leadership', 'ROLE'), ('track record', 'SKILL'), ('lead', 'ROLE'), ('compliance', 'ROLE'), ('deployment', 'SKILL'), ('pharma', 'DEPT'), ('application', 'SKILL'), ('information systems', 'SKILL'), ('bi', 'SKILL'), ('information security', 'DEPT'), ('senior management', 'ROLE'), ('support', 'SKILL'), ('sap', 'SKILL'), ('salesforce', 'SKILL'), ('applications', 'SKILL'), ('development', 'SKILL'), ('information technology', 'DEPT'), ('operations', 'DEPT'), ('developing', 'SKILL'), ('testing', 'SKILL'), ('project management', 'ROLE'), ('decision making', 'SKILL'), ('budget', 'SKILL'), ('analytics', 'DEPT')}
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">description scope role piramal
# <mark class="entity" style="background: #E7A1B0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pharma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DEPT</span>
# </mark>
#  solutions pps chief information officer cio role provide vision
# <mark class="entity" style="background: #8EEBEC; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     leadership
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ROLE</span>
# </mark>
#
# <mark class="entity" style="background: #FFF380; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     developing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  implementing
# <mark class="entity" style="background: #E7A1B0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     information technology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DEPT</span>
# </mark>
#  initiatives align vision piramal pharma solutions pps businesses pps cio charter build competitive edge business proactively building world class high quality innovative technology digital
# <mark class="entity" style="background: #E7A1B0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     analytics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DEPT</span>
# </mark>
#  solutions global
# <mark class="entity" style="background: #E7A1B0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     operations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DEPT</span>
# </mark>
#  job overview strategy innovation strategic business partner create enhanced digital technology vision enterprise identify opportunities differentiated technology capabilities solutions p roactively recommend solutions business functional
# <mark class="entity" style="background: #8EEBEC; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     leadership
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ROLE</span>
# </mark>
#  team considering business vision industry trends bringing outside perspective p ush bar technology innovation imbibing cutting edge technological innovations global benchmarks blue sky thinking create user friendly technologies offering great experience cts champion change agent accelerating organizational changes required create sustain enterprise technology capabilities cts thought leader emerging digital business models technologies articulating digital future enterprise role internally externally enable business growth enable inorganic business growth merger acquisition leading due diligence driving integration post acquisition
# <mark class="entity" style="background: #8EEBEC; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lead
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ROLE</span>
# </mark>
#  strategic operational planning implementation achieve business goals fostering innovation prioritizing initiatives coordinating evaluation
# <mark class="entity" style="background: #FFF380; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     deployment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  management current future systems across organization coordinate facilitate consultation relevant business stakeholders define business systems requirements new technology implementations planning execution partner various site ho teams manage project portfolio relate selection acquisition
# <mark class="entity" style="background: #FFF380; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     development
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  implementation major
# <mark class="entity" style="background: #FFF380; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     information systems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  defines governance mechanism metrics review progress technology projects business case achievement technology
# <mark class="entity" style="background: #FFF380; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     budget
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  company provide upfront estimates costs various heads keep track spends ensure best roi company technology investment maintaining balance frugality financial discipline adequately gearing future growth b uild ecosystem group technology teams partners including startups product vendors develop implement technology solutions b uild future read technology team attracting retaining upskilling industry best talent
# <mark class="entity" style="background: #8EEBEC; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     compliance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ROLE</span>
# </mark>
#
# <mark class="entity" style="background: #E7A1B0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     information security
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DEPT</span>
# </mark>
#  collaborate piramal quality e compliance qec team ensure quality compliance per defined sops guidelines accordance 21 cfr part 11 gamp guidelines collaborate information security team ensure adherence information security guidelines processes skills abilities exceptional inter personal skills enabling engagement levels across
# <mark class="entity" style="background: #8EEBEC; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     leadership
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ROLE</span>
# </mark>
#  skills including ability manage large team understanding strategy business technology
# <mark class="entity" style="background: #FFF380; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     application
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  levels environment priorities goals quickly change evolve also skills think strategically including
# <mark class="entity" style="background: #FFF380; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     developing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  i
